# %% [markdown]
# # E-tivity 1 (27/01/25 - 09/02/25)
#
# * Sean Noonan
#
# * 23300159

# %% [markdown]
# ## Anomaly Detection
#
# ### Context
# We have a mystery dataset. There are 9 explanatory variables and one response variable. The response variable is the last column and indicates if the sample is anomalous (=1, valid =0). The dataset is provided "data.csv".
#
# Of course in this case we could use supervised learning to generate a model and detect anomalies in new data. However the focus is on autoencoders, anomaly detection is just one of the potential uses for autoencoders.
#
# So we are going to pretend that we do not know which data are anomalous but we do know that the anomaly rate is small. Use an autoencoder to detect anomalies in the data. The correctness of the model can of course be checked.

# %% [markdown]
# ### Guidelines
#
# The e-tivity is split into four tasks. The first three are "group" excersises, in that you post the solutions to Tasks 1-3 to a site. This will allow the members of your group to send you feedback (via the forums) so you can improve your submission. The final task is an individual task and together with the other tasks, should be uploaded to the Group Locker.
#
# Marks will be deducted if task 4 is uploaded in contravention of instructions. Also if the the final submission is not a single notebook with tasks 1-4 and with correct identification or filename.
#
# Grading guidelines: the scores for each task are additive. Below is a link to the E-tivity rubrics.
#
# https://learn.ul.ie/d2l/lp/rubrics/preview.d2l?ou=49284&rubricId=2620&originTool=quicklinks

# %% [markdown]
# ## Problem
#
# If you train even a modest feed forward network via supervised learning you can get extremely good recall and precision, despite the unbalanced dataset. However in this e-tivity you will determining the anomalies by using an autoencoder. That is you will **not** be using the Anom flag to guide the training.
#
# The mystery dataset is available from Brightspace, download the csv file and use it as the input data.
#
# ### Tasks 1-3 (complete by Sunday 02/02/25)
#
# The initial implementation of the tasks are to be uploaded to the locker on which the other group members can comment. The forum activity will form part of the overall mark for the e-tivity.

# %% [markdown]
# **Task 1: data preprocessing**
#
# Explain any preprocessing steps you take and also how you have selected the training and test sets. Remember we do not know which samples are anomalous only that there are a small number of them compared to the total sample size.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data.csv")

# %% [markdown]
# ## Quick peep at data

# %%
# Lets have a look at the data
df.head()
# Out:
#    V1  V2  V3  V4  V5  V6  V7  V8  V9  Anom
# 0  50  21  77   0  28   0  27  48  22     1
# 1  53   0  82   0  52  -5  29  30   2     0
# 2  37   0  76   0  28  18  40  48   8     0
# 3  37   0  79   0  34 -26  43  46   2     0
# 4  85   0  88  -4   6   1   3  83  80     1

# %%
print(df.count())
# Out:
# V1      49097
# V2      49097
# V3      49097
# V4      49097
# V5      49097
# V6      49097
# V7      49097
# V8      49097
# V9      49097
# Anom    49097
# dtype: int64

# %%
# Print statistical summary for all numerical attributes
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  49097.000000  49097.000000  49097.000000  49097.000000  49097.000000
# mean      46.932399     -0.063955     85.123124      0.213231     36.871784
# std       12.875159     84.674481      8.877517     37.579171     19.963113
# min       27.000000  -4821.000000     21.000000  -3939.000000   -188.000000
# 25%       37.000000      0.000000     79.000000      0.000000     30.000000
# 50%       44.000000      0.000000     83.000000      0.000000     42.000000
# 75%       50.000000      0.000000     88.000000      0.000000     46.000000
# max      126.000000   5075.000000    149.000000   3830.000000    436.000000
#
#                  V6            V7            V8            V9          Anom
# count  49097.000000  49097.000000  49097.000000  49097.000000  49097.000000
# mean       2.160030     38.200725     48.288592     10.261930      0.071511
# std      218.324964     13.446306     20.572064     23.751024      0.257680
# min   -26739.000000    -48.000000   -353.000000   -356.000000      0.000000
# 25%       -4.000000     33.000000     35.000000      0.000000      0.000000
# 50%        0.000000     39.000000     41.000000      2.000000      0.000000
# 75%        5.000000     43.000000     55.000000      6.000000      0.000000
# max    15164.000000    105.000000    270.000000    266.000000      1.000000

# %% [markdown]
# There is a wide range of values here. Scaling will be useful in ppreprocessing. There are 50k samples and 9 features. This is plenty of datapoints.

# %%
numerical_columns = df.select_dtypes(include=['number']).columns
missing_numerical = df[numerical_columns].isnull().sum()

print("Missing values in numerical variables:")
print(missing_numerical)
# Out:
# Missing values in numerical variables:
# V1      0
# V2      0
# V3      0
# V4      0
# V5      0
# V6      0
# V7      0
# V8      0
# V9      0
# Anom    0
# dtype: int64

# %%
# Count rows where the 'Anom' column is equal to 1
num_anomalies = df[df['Anom'] == 1].shape[0]

print(f"Number of rows with 'Anom' = 1: {num_anomalies}")
# Out:
# Number of rows with 'Anom' = 1: 3511

# %% [markdown]
# So we have 49k records and 3.5 k anomalies

# %%
3511/49097
# Out:
# 0.0715114976475141

# %% [markdown]
# We have a 7% anomally rate

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = df.corr()

# Display the matrix as a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Add title
plt.title("Correlation Matrix")

# Show the plot
plt.show()

# %% [markdown]
# There are a lot of strong correlations visible

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42)

# Print sizes to verify
print(f"Training set size: {len(df_train)}")
print(f"Testing set size: {len(df_test)}")
# Out:
# Training set size: 34367
# Testing set size: 14730

# %%
from sklearn.model_selection import train_test_split

# Assuming df has the column 'ANOM' where anomalies are labeled as 1 and normal data as 0
X = df.drop('Anom', axis=1)  # All columns except the target column 'ANOM'
y = df['Anom']  # The target variable that contains anomalies (1) and normal (0)

# Stratified split to ensure same proportion of anomalies in train and test
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42, stratify=y)

# Check the proportions in the split
print("Train anomaly distribution:\n", df_train['Anom'].value_counts(normalize=True))
print("Test anomaly distribution:\n", df_test['Anom'].value_counts(normalize=True))
# Out:
# Train anomaly distribution:
#  Anom
# 0    0.928478
# 1    0.071522
# Name: proportion, dtype: float64
# Test anomaly distribution:
#  Anom
# 0    0.928513
# 1    0.071487
# Name: proportion, dtype: float64

# %% [markdown]
# The training and test set must be split before any preprocessing. This split should ensure equal number sof anomalies in both.

# %% [markdown]
# Set up the labelled and unlabelled data

# %%
X_train = df_train.drop("Anom", axis=1)
Y_train = df_train[['Anom']].copy()
X_test = df_test.drop("Anom", axis=1)
Y_test = df_test[['Anom']].copy()

# %% [markdown]
# **Task 2: model generation and training**
#
# Generate a suitable autoencoder model, the only restriction is that there should be only 2 latent variables. Train the model to a satistifactory result. Be aware that it will be much harder to achieve the sort of result you can get from a supervised learning model.
#
# **Hint**: it should not take longer than a 1000 epochs to train. However it may be difficult to train. Use different optimizers, topologies and/or weight initialisations to get convergence. Remember that achieving a perfect error means that the model will also be good at reconstructing anomalies.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# Load the module we need
# Note that we are import the Keras backend, which is assumed to be Tensorflow
from tensorflow.keras.layers import UpSampling2D, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras import backend as K


from tensorflow.keras.layers import Lambda
from tensorflow.keras.losses import mean_squared_error, binary_crossentropy, mse, KLDivergence
from tensorflow.keras.utils import plot_model

import tensorflow as tf
import os

# %%
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# Example dataset (replace `df_unlabelled` with your own data)
# data_train = X_train.values

# Normalize the data to [0, 1], need toi do on test and train separately to void data snooping
scaler = MinMaxScaler()
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# data_test = X_test.values

X_test = scaler.fit_transform(X_test)

# Dimensions of the input data
input_dim = X_train.shape[1]
print(input_dim)
# Out:
# 9

# %%
# pip install pydot

# %%
# pip install graphviz

# %%
# Define the Encoder, inputs are the MNIST 28x28 greyscale images 
inputs = layers.Input(shape=(input_dim,))
x = layers.Dense(6, activation='relu', kernel_initializer='he_normal')(inputs)
x = layers.Dense(4, activation='relu', kernel_initializer='he_normal')(x)
latent = layers.Dense(2, activation='linear', name='latent_space')(x)  # 2 latent variables

encoded = Model(inputs,latent,name='encoded')
encoded.summary()
# plot_model(encoded, to_file='AE_encoded_etiv.png', show_shapes=True)            

# Latent space is a 5 dimensional vector space

# This is the decoder, it take the 5 dim latent vector and generates a 28x28 image
# lats = Input(shape=(2,),name='latent')
# Decoder
latent_inputs = layers.Input(shape=(2,))
x = layers.Dense(4, activation='relu', kernel_initializer='he_normal')(latent_inputs)
x = layers.Dense(6, activation='relu', kernel_initializer='he_normal')(x)
outputs = layers.Dense(input_dim, activation='sigmoid')(x)  # Sigmoid to ensure output in [0, 1]

decoded = Model(latent_inputs,outputs,name='decoded')
decoded.summary()
# plot_model(decoded, to_file='AE_decoded_etiv.png', show_shapes=True)     

# The autoencoder takes the image as input encodes it, then decodes it
rec = decoded(encoded(inputs))
autoencoder = Model(inputs,rec,name="AE")

reconstructions = autoencoder.predict(X_test)
reconstruction_loss = np.mean(np.square(reconstructions - X_test), axis=1)
# autoencoder.add_loss(lambda: reconstruction_loss) 
autoencoder.summary()
# Out:
# Model: "encoded"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 9)]               0
#
#  dense_50 (Dense)            (None, 6)                 60
#
#  dense_51 (Dense)            (None, 4)                 28
#
#  latent_space (Dense)        (None, 2)                 10
#
# =================================================================
# Total params: 98 (392.00 Byte)
# Trainable params: 98 (392.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "decoded"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 2)]               0
#
#  dense_52 (Dense)            (None, 4)                 12
#
#  dense_53 (Dense)            (None, 6)                 30
#
#  dense_54 (Dense)            (None, 9)                 63
#
# =================================================================
# Total params: 105 (420.00 Byte)
# Trainable params: 105 (420.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 461/461 [==============================] - 1s 1ms/step
# Model: "AE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 9)]               0
#
#  encoded (Functional)        (None, 2)                 98
#
#  decoded (Functional)        (None, 9)                 105
#
# =================================================================
# Total params: 203 (812.00 Byte)
# Trainable params: 203 (812.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse')

# %%
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mae')

# %%
# Train the autoencoder
history = autoencoder.fit(
    X_train,
    X_train,  # Input and output are the same for an autoencoder
    validation_data=(X_test, X_test),
    epochs=150,
    batch_size=32,
    shuffle=True,
    verbose=2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    ]
)
# Out:
# Epoch 1/150
# 1074/1074 - 3s - loss: 0.4645 - val_loss: 0.3919 - 3s/epoch - 3ms/step
# Epoch 2/150
# 1074/1074 - 2s - loss: 0.3856 - val_loss: 0.3855 - 2s/epoch - 2ms/step
# Epoch 3/150
# 1074/1074 - 2s - loss: 0.3806 - val_loss: 0.3796 - 2s/epoch - 2ms/step
# Epoch 4/150
# 1074/1074 - 2s - loss: 0.3741 - val_loss: 0.3741 - 2s/epoch - 2ms/step
# Epoch 5/150
# 1074/1074 - 2s - loss: 0.3714 - val_loss: 0.3739 - 2s/epoch - 2ms/step
# Epoch 6/150
# 1074/1074 - 2s - loss: 0.3706 - val_loss: 0.3726 - 2s/epoch - 2ms/step
# Epoch 7/150
# 1074/1074 - 2s - loss: 0.3701 - val_loss: 0.3721 - 2s/epoch - 2ms/step
# Epoch 8/150
# 1074/1074 - 2s - loss: 0.3696 - val_loss: 0.3720 - 2s/epoch - 2ms/step
# Epoch 9/150
# 1074/1074 - 2s - loss: 0.3692 - val_loss: 0.3713 - 2s/epoch - 2ms/step
# Epoch 10/150
# 1074/1074 - 2s - loss: 0.3685 - val_loss: 0.3707 - 2s/epoch - 2ms/step
# Epoch 11/150
# 1074/1074 - 2s - loss: 0.3680 - val_loss: 0.3701 - 2s/epoch - 2ms/step
# Epoch 12/150
# 1074/1074 - 2s - loss: 0.3678 - val_loss: 0.3699 - 2s/epoch - 2ms/step
# Epoch 13/150
# 1074/1074 - 2s - loss: 0.3675 - val_loss: 0.3700 - 2s/epoch - 2ms/step
# Epoch 14/150
# 1074/1074 - 2s - loss: 0.3673 - val_loss: 0.3694 - 2s/epoch - 2ms/step
# Epoch 15/150
# 1074/1074 - 2s - loss: 0.3672 - val_loss: 0.3696 - 2s/epoch - 2ms/step
# Epoch 16/150
# 1074/1074 - 2s - loss: 0.3671 - val_loss: 0.3701 - 2s/epoch - 2ms/step
# Epoch 17/150
# 1074/1074 - 2s - loss: 0.3666 - val_loss: 0.3613 - 2s/epoch - 2ms/step
# Epoch 18/150
# 1074/1074 - 2s - loss: 0.3550 - val_loss: 0.3564 - 2s/epoch - 2ms/step
# Epoch 19/150
# 1074/1074 - 2s - loss: 0.3537 - val_loss: 0.3565 - 2s/epoch - 2ms/step
# Epoch 20/150
# 1074/1074 - 2s - loss: 0.3537 - val_loss: 0.3562 - 2s/epoch - 2ms/step
# Epoch 21/150
# 1074/1074 - 2s - loss: 0.3535 - val_loss: 0.3563 - 2s/epoch - 2ms/step
# Epoch 22/150
# 1074/1074 - 2s - loss: 0.3535 - val_loss: 0.3567 - 2s/epoch - 2ms/step
# Epoch 23/150
# 1074/1074 - 2s - loss: 0.3535 - val_loss: 0.3558 - 2s/epoch - 2ms/step
# Epoch 24/150
# 1074/1074 - 2s - loss: 0.3534 - val_loss: 0.3559 - 2s/epoch - 2ms/step
# Epoch 25/150
# 1074/1074 - 2s - loss: 0.3534 - val_loss: 0.3564 - 2s/epoch - 2ms/step
# Epoch 26/150
# 1074/1074 - 2s - loss: 0.3533 - val_loss: 0.3558 - 2s/epoch - 2ms/step
# Epoch 27/150
# 1074/1074 - 2s - loss: 0.3531 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 28/150
# 1074/1074 - 2s - loss: 0.3531 - val_loss: 0.3556 - 2s/epoch - 2ms/step
# Epoch 29/150
# 1074/1074 - 2s - loss: 0.3530 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 30/150
# 1074/1074 - 2s - loss: 0.3530 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 31/150
# 1074/1074 - 2s - loss: 0.3530 - val_loss: 0.3557 - 2s/epoch - 2ms/step
# Epoch 32/150
# 1074/1074 - 2s - loss: 0.3529 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 33/150
# 1074/1074 - 2s - loss: 0.3529 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 34/150
# 1074/1074 - 2s - loss: 0.3529 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 35/150
# 1074/1074 - 2s - loss: 0.3529 - val_loss: 0.3560 - 2s/epoch - 2ms/step
# Epoch 36/150
# 1074/1074 - 2s - loss: 0.3528 - val_loss: 0.3556 - 2s/epoch - 2ms/step
# Epoch 37/150
# 1074/1074 - 2s - loss: 0.3529 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 38/150
# 1074/1074 - 2s - loss: 0.3528 - val_loss: 0.3556 - 2s/epoch - 2ms/step
# Epoch 39/150
# 1074/1074 - 2s - loss: 0.3528 - val_loss: 0.3556 - 2s/epoch - 2ms/step
# Epoch 40/150
# 1074/1074 - 2s - loss: 0.3528 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 41/150
# 1074/1074 - 2s - loss: 0.3528 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 42/150
# 1074/1074 - 2s - loss: 0.3528 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 43/150
# 1074/1074 - 2s - loss: 0.3528 - val_loss: 0.3556 - 2s/epoch - 2ms/step
# Epoch 44/150
# 1074/1074 - 2s - loss: 0.3528 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 45/150
# 1074/1074 - 2s - loss: 0.3527 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 46/150
# 1074/1074 - 2s - loss: 0.3527 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 47/150
# 1074/1074 - 2s - loss: 0.3527 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 48/150
# 1074/1074 - 2s - loss: 0.3527 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 49/150
# 1074/1074 - 2s - loss: 0.3527 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 50/150
# 1074/1074 - 2s - loss: 0.3527 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 51/150
# 1074/1074 - 2s - loss: 0.3527 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 52/150
# 1074/1074 - 2s - loss: 0.3527 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 53/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 54/150
# 1074/1074 - 2s - loss: 0.3527 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 55/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 56/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 57/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 58/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 59/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 60/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 61/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 62/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 63/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 64/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 65/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 66/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 67/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 68/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 69/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 70/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 71/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 72/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 73/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 74/150
# 1074/1074 - 2s - loss: 0.3526 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 75/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 76/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 77/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 78/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 79/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 80/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 81/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 82/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 83/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 84/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3549 - 2s/epoch - 2ms/step
# Epoch 85/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3549 - 2s/epoch - 2ms/step
# Epoch 86/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 87/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 88/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 89/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 90/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3554 - 2s/epoch - 2ms/step
# Epoch 91/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 92/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 93/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 94/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 95/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 96/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 97/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 98/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 99/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3549 - 2s/epoch - 2ms/step
# Epoch 100/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3555 - 2s/epoch - 2ms/step
# Epoch 101/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 102/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 103/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 104/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 105/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3549 - 2s/epoch - 2ms/step
# Epoch 106/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3549 - 2s/epoch - 2ms/step
# Epoch 107/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3549 - 2s/epoch - 2ms/step
# Epoch 108/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 109/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 110/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 111/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 112/150
# 1074/1074 - 2s - loss: 0.3524 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 113/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 114/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 115/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 116/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 117/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3549 - 2s/epoch - 2ms/step
# Epoch 118/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 119/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3553 - 2s/epoch - 2ms/step
# Epoch 120/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3547 - 2s/epoch - 2ms/step
# Epoch 121/150
# 1074/1074 - 2s - loss: 0.3522 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 122/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3547 - 2s/epoch - 2ms/step
# Epoch 123/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 124/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3550 - 2s/epoch - 2ms/step
# Epoch 125/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 126/150
# 1074/1074 - 2s - loss: 0.3522 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 127/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3547 - 3s/epoch - 3ms/step
# Epoch 128/150
# 1074/1074 - 3s - loss: 0.3523 - val_loss: 0.3554 - 3s/epoch - 3ms/step
# Epoch 129/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3549 - 3s/epoch - 3ms/step
# Epoch 130/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3549 - 3s/epoch - 3ms/step
# Epoch 131/150
# 1074/1074 - 3s - loss: 0.3523 - val_loss: 0.3552 - 3s/epoch - 3ms/step
# Epoch 132/150
# 1074/1074 - 3s - loss: 0.3523 - val_loss: 0.3549 - 3s/epoch - 3ms/step
# Epoch 133/150
# 1074/1074 - 3s - loss: 0.3523 - val_loss: 0.3548 - 3s/epoch - 3ms/step
# Epoch 134/150
# 1074/1074 - 3s - loss: 0.3523 - val_loss: 0.3554 - 3s/epoch - 3ms/step
# Epoch 135/150
# 1074/1074 - 3s - loss: 0.3523 - val_loss: 0.3553 - 3s/epoch - 3ms/step
# Epoch 136/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3552 - 3s/epoch - 3ms/step
# Epoch 137/150
# 1074/1074 - 3s - loss: 0.3523 - val_loss: 0.3547 - 3s/epoch - 3ms/step
# Epoch 138/150
# 1074/1074 - 2s - loss: 0.3523 - val_loss: 0.3546 - 2s/epoch - 2ms/step
# Epoch 139/150
# 1074/1074 - 2s - loss: 0.3522 - val_loss: 0.3547 - 2s/epoch - 2ms/step
# Epoch 140/150
# 1074/1074 - 2s - loss: 0.3522 - val_loss: 0.3549 - 2s/epoch - 2ms/step
# Epoch 141/150
# 1074/1074 - 2s - loss: 0.3522 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 142/150
# 1074/1074 - 2s - loss: 0.3522 - val_loss: 0.3551 - 2s/epoch - 2ms/step
# Epoch 143/150
# 1074/1074 - 2s - loss: 0.3522 - val_loss: 0.3548 - 2s/epoch - 2ms/step
# Epoch 144/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3548 - 3s/epoch - 2ms/step
# Epoch 145/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3551 - 3s/epoch - 3ms/step
# Epoch 146/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3550 - 3s/epoch - 3ms/step
# Epoch 147/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3547 - 3s/epoch - 3ms/step
# Epoch 148/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3547 - 3s/epoch - 3ms/step
# Epoch 149/150
# 1074/1074 - 3s - loss: 0.3522 - val_loss: 0.3548 - 3s/epoch - 3ms/step
# Epoch 150/150
# 1074/1074 - 2s - loss: 0.3522 - val_loss: 0.3548 - 2s/epoch - 2ms/step

# %%
autoencoder.save_weights('ae_mlp.h5')

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MAE)')
plt.legend()
plt.title('Autoencoder Training Performance')
plt.show()

# %% [markdown]
# Training after 120 epochs dose not lead to any accuracy increase. Training has saturated.

# %%
# Evaluate on test data
reconstructions = autoencoder.predict(X_test)
reconstruction_loss = np.mean(np.square(reconstructions - X_test), axis=1)

print(f"Mean Reconstruction Loss on Test Data: {np.mean(reconstruction_loss):.4f}")
# Out:
# 461/461 [==============================] - 1s 1ms/step
# Mean Reconstruction Loss on Test Data: 0.8011

# %% [markdown]
# **Task 3: anomaly detection**
#
# From the histogram of the reconstruction error decide what the cutoff should be applied to distinguish anomalies from valid samples, given that the anomaly rate is ~7%.

# %%
import numpy as np

# Get reconstructed values for the test data
reconstructions = autoencoder.predict(X_test)

# Calculate reconstruction error for each sample
reconstruction_errors = np.mean(np.square(reconstructions - X_test), axis=1)
# Out:
# 461/461 [==============================] - 1s 1ms/step

# %%
import matplotlib.pyplot as plt

# Plot the histogram
plt.hist(reconstruction_errors, bins=50, alpha=0.7, color='blue')
plt.xlabel("Reconstruction Error")
plt.ylabel("Frequency")
plt.title("Histogram of Reconstruction Errors")
plt.show()

# %%
# Calculate the 95th percentile as the cutoff for anomalies
threshold = np.percentile(reconstruction_errors, 95)

# Print the threshold
print(f"Cutoff Threshold for Anomalies: {threshold:.4f}")
# Out:
# Cutoff Threshold for Anomalies: 2.9206

# %%
# Classify samples as anomalies
anomalies = reconstruction_errors > threshold

# Print the number of anomalies
print(f"Number of anomalies: {np.sum(anomalies)}")
# Out:
# Number of anomalies: 737

# %%
# Get the total number of arrays (rows) in the 2D array
num_rows = X_test.shape[0]

# Print the number of rows (arrays)
print(f"Total number of arrays (rows): {num_rows}")
# Out:
# Total number of arrays (rows): 14730

# %%
print(np.sum(anomalies)/num_rows)
# Out:
# 0.050033944331296674

# %%
# Extract the anomalous rows from the test data
anomalous_samples = X_test[anomalies]

# Optionally, display the anomalous samples
print("Anomalous Samples:")
print(anomalous_samples)
# Out:
# Anomalous Samples:
# [[ 2.34843921e+00  2.81376347e-02 -4.59504544e-01 ... -2.55541686e+00
#    3.66518633e+00  4.56948875e+00]
#  [ 2.81618051e+00  3.90402896e-03  1.07685187e-01 ... -2.63017226e+00
#    2.24463901e+00  3.38305985e+00]
#  [ 2.50435298e+00  3.90402896e-03 -1.19190706e-01 ... -2.55541686e+00
#    3.66518633e+00  4.56948875e+00]
#  ...
#  [ 2.66026675e+00  5.23712405e-02 -1.19190706e-01 ... -2.55541686e+00
#    2.78346731e+00  3.89152938e+00]
#  [ 2.66026675e+00 -3.24463797e-02 -5.75275939e-03 ... -2.55541686e+00
#    3.81213950e+00  4.73897860e+00]
#  [ 2.58230986e+00  3.90402896e-03 -1.19190706e-01 ... -2.55541686e+00
#    3.91010828e+00  4.82372352e+00]]

# %%
# Transform the training data into the latent space
latent_space = encoded.predict(X_train)

# Plot the latent space
import matplotlib.pyplot as plt

plt.scatter(latent_space[:, 0], latent_space[:, 1], c='blue', alpha=0.5)
plt.xlabel('Latent Variable 1')
plt.ylabel('Latent Variable 2')
plt.title('Latent Space Visualization')
plt.grid(True)
plt.show()
# Out:
# 1074/1074 [==============================] - 1s 1ms/step

# %% [markdown]
# There is some structure with clusters. As expected for an autoencoder this structure is not very symmetric. The anomalies are presumably the onesfar from the dense cluster.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Transform the training data into the latent space
latent_space = encoded.predict(X_train)

# Ensure Y_train is a NumPy array and flattened
Y_train_array = np.array(Y_train).flatten()  # Convert to a 1D NumPy array if it's a DataFrame or Series

# Define colors: Normal samples (blue), Anomalies (red)
colors = np.array(['blue'] * len(Y_train_array))  # Default all to blue
colors[Y_train_array == 1] = 'red'  # Set anomalies to red

# Plot the latent space with different colors for anomalies
plt.figure(figsize=(8, 6))
plt.scatter(latent_space[:, 0], latent_space[:, 1], c=colors, alpha=0.5)
plt.xlabel('Latent Variable 1')
plt.ylabel('Latent Variable 2')
plt.title('Latent Space Visualization')
plt.grid(True)

# Add legend
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Normal', markersize=8, markerfacecolor='blue'),
                   Line2D([0], [0], marker='o', color='w', label='Anomaly', markersize=8, markerfacecolor='red')]
plt.legend(handles=legend_elements)

plt.show()
# Out:
# 1074/1074 [==============================] - 1s 1ms/step

# %% [markdown]
# As expected the actual anomalies are outside of the main cluster. Each time I run this I get a different cluster.

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Step 1: Get model predictions (Reconstruction Errors)
reconstructions = autoencoder.predict(X_test)  # X_test is the test data
reconstruction_errors = np.mean(np.square(X_test - reconstructions), axis=1)

# Step 2: Set an anomaly detection threshold (e.g., 95th percentile)
threshold = np.percentile(reconstruction_errors, 95)

# Step 3: Predict anomalies based on threshold
y_pred = (reconstruction_errors > threshold).astype(int)  # 1 = Anomaly, 0 = Normal

# Step 4: Get actual labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual anomaly labels

# Step 5: Compute Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Step 6: Plot Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Step 7: Print Classification Report
print(classification_report(y_true, y_pred))
# Out:
# 461/461 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     13677
#            1       0.98      0.68      0.80      1053
#
#     accuracy                           0.98     14730
#    macro avg       0.98      0.84      0.90     14730
# weighted avg       0.98      0.98      0.97     14730

# %%
print(cm)
# Out:
# [[13659    18]
#  [  334   719]]

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc

# Step 1: Get model predictions (Reconstruction Errors)
reconstructions = autoencoder.predict(X_test)  
reconstruction_errors = np.mean(np.square(X_test - reconstructions), axis=1)

# Step 2: Get actual labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual anomaly labels

# Step 3: Compute ROC Curve
fpr, tpr, thresholds = roc_curve(y_true, reconstruction_errors)

# Step 4: Compute AUC (Area Under Curve)
roc_auc = auc(fpr, tpr)

# Step 5: Plot ROC Curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal reference line

# Display AUC score on plot
plt.text(0.6, 0.2, f'AUC = {roc_auc:.2f}', fontsize=12, bbox=dict(facecolor='white', alpha=0.7))

# Formatting
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid()

# Show plot
plt.show()
# Out:
# 461/461 [==============================] - 1s 1ms/step

# %% [markdown]
# This is a very high AUC

# %% [markdown]
# Lets use the ROC cureve to find the best Threshold

# %%
# Compute Youden's J statistic
youden_j = tpr - fpr
best_index = np.argmax(youden_j)  # Index of max Youden's J
best_threshold = thresholds[best_index]

# %% [markdown]
# Now lets print the anomalies

# %%
y_pred = (reconstruction_errors > best_threshold).astype(int)  # 1 = Anomaly, 0 = Normal
# Step 4: Get actual labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual anomaly labels

# Step 5: Compute Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Step 6: Plot Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Step 7: Print Classification Report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     13677
#            1       0.79      0.96      0.86      1053
#
#     accuracy                           0.98     14730
#    macro avg       0.89      0.97      0.93     14730
# weighted avg       0.98      0.98      0.98     14730

# %% [markdown]
# This is very accurate. Anomalies have 1. F1 scoe of 0.921 is high.

# %% [markdown]
# ### Post (complete by Sunday 02/02/25)
#
# Once you have an implemntation however rough, use the forums/topics to advertise the fact. The purpose is to get feedback from others in the group, so if you have only a basic outline then you may get ideas about how to proceed and also examples from others in your group.
#
# No posts should refer to Task 4.

# %% [markdown]
# ### Respond (complete by Wednesday 05/02/24)
#
# If you feel you can provide useful advise then respond to another member of the group through the appropriate forum. Responses should be respectful and offer some sort of advise. Try and avoid clogging the forums with support or thank you messages.
#
# In reviewing others code you will discover different ways to tackle the same problem. It is acceptable to copy parts of others code. However whole scale copying from another notebook is not acceptable.
#
# If you stick to the deadline then it will allow yourself and others to have enough time to implement suggestions. From the Schedule you can see that this is not a hard deadline.
#
# The posts on the forum/topic associated with this e-tivity are graded. Below is a link to the rubrics.
#
# https://learn.ul.ie/d2l/lp/rubrics/preview.d2l?ou=49284&rubricId=2620&originTool=quicklinks

# %% [markdown]
# ### Task 4: VAE (completed by Sunday 09/02/24)
#
# This task is a individual task and should **not** to be uploaded to the Group Locker. No direct support should be given via the forums. Marks will be deducted if the instructions are not followed (see rubrics). This part should be uploaded directly to Brightpsace.
#
# Change the network to be a VAE. Again determine the optimal cutoff and plot the latent variables. Check how good the cutoffs were by constructing a confusion matrix or generating a classification report. Obviously for this task you need to use the Anom column.
#
# **Hint** you can use the model topology from the AE (with the obvious modifications). I found that I had a good model (almost as good and the supervised learning model) when the KL divergence was small. You can print out both the KL divergence and reconstruction loss for each epoch. It can be tricky to train these type of models, so do not be surprised if you do not get a stellar result. What is more important is that you have the correct code to implement the VAE.

# %% [markdown]
# ### Final Submission (complete by Sunday 09/02/24)
#
# Submit Tasks 1-4 in a single notebook this before the deadline on Sunday.

# %%
## Add additional code cells to implememt the tasks stated above

# %%
sc = StandardScaler() 
X_train_scaled = sc.fit_transform(X_train) 
X_test_scaled = sc.fit_transform(X_test) 

input_layer = layers.Input(shape=(input_dim,)) #Define input layer
x = Dense(10,activation='relu')(input_layer) 
#z_mean = Dense(2,activation='relu',name='z_mean')(x) 
z_mean = Dense(2,name='z_mean')(x) # Should be no activation
#z_log_var = Dense(2, name='z_log_var',activation='selu')(x) 
z_log_var = Dense(2, name='z_log_var',activation='linear')(x) # selu is not good for variance

z = Lambda(sampling, output_shape=(2,), name='z')([z_mean, z_log_var]) 
encoder = Model(inputs, [z_mean, z_log_var, z], name='encoder') 

latent_inputs = layers.Input(shape=(latent_dim,)) #Define latent inputs
x = Dense(units=2,activation='linear')(latent_inputs) 
#outputs = Dense(units=5, activation='sigmoid')(x) 
outputs = Dense(units=10, activation='sigmoid')(x) #The number of neurons for output should be the same as that for input.

decoder = Model(latent_inputs, outputs, name='decoder')

#outputs = decoder(encoder(input_layer)[2])
reconstructions = decoder(encoder(input_layer)[2]) # Make clear these are now reconstructions of inputs
#vae = Model(input_layer, outputs, name='vae_inerror')
vae = Model(input_layer, reconstructions, name='vae_fixed')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sc = StandardScaler()
#       2 X_train_scaled = sc.fit_transform(X_train)
#       3 X_test_scaled = sc.fit_transform(X_test)
#
# NameError: name 'StandardScaler' is not defined

# %%
import tensorflow.keras.backend as K

latent_dim = 2  # Latent space with 2 variables

# ---- Encoder ----
inputs = layers.Input(shape=(input_dim,))
x = layers.Dense(6, activation='relu', kernel_initializer='he_normal')(inputs)
x = layers.Dense(4, activation='relu', kernel_initializer='he_normal')(x)

# Latent space: Mean and Log Variance
z_mean = layers.Dense(latent_dim, name='z_mean')(x)
z_log_var = layers.Dense(latent_dim, name='z_log_var',activation='linear')(x)

# Reparameterization Trick
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=K.shape(z_mean))  # Noise
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

z = layers.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

# Encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()


# ---- Decoder ----
latent_inputs = layers.Input(shape=(latent_dim,))
x = layers.Dense(4, activation='relu', kernel_initializer='he_normal')(latent_inputs)
x = layers.Dense(6, activation='relu', kernel_initializer='he_normal')(x)
outputs = layers.Dense(input_dim, activation='sigmoid')(x)  # Sigmoid for pixel intensity

# Decoder model
decoder = Model(latent_inputs, outputs, name="decoder")
decoder.summary()


# ---- VAE Model ----
z_mean, z_log_var, z = encoder(inputs)
reconstructions1 = decoder(z)

vae = Model(inputs, reconstructions1, name="vae")

# Summary
vae.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_23 (InputLayer)       [(None, 9)]                  0         []
#
#  dense_55 (Dense)            (None, 6)                    60        ['input_23[0][0]']
#
#  dense_56 (Dense)            (None, 4)                    28        ['dense_55[0][0]']
#
#  z_mean (Dense)              (None, 2)                    10        ['dense_56[0][0]']
#
#  z_log_var (Dense)           (None, 2)                    10        ['dense_56[0][0]']
#
#  z (Lambda)                  (None, 2)                    0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 108 (432.00 Byte)
# Trainable params: 108 (432.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 2)]               0
#
#  dense_57 (Dense)            (None, 4)                 12
#
#  dense_58 (Dense)            (None, 6)                 30
#
#  dense_59 (Dense)            (None, 9)                 63
#
# =================================================================
# Total params: 105 (420.00 Byte)
# Trainable params: 105 (420.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "vae"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 9)]               0
#
#  encoder (Functional)        [(None, 2),               108
#                               (None, 2),
#                               (None, 2)]
#
#  decoder (Functional)        (None, 9)                 105
#
# =================================================================
# Total params: 213 (852.00 Byte)
# Trainable params: 213 (852.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Calculate reconstruction loss (Mean Squared Error)
reconstruction_loss = K.mean(K.square(reconstructions1 - inputs), axis=1)

# KL divergence loss (regularization)
z = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = -0.5 * K.sum(z, axis=-1)  # Sum over the latent dimension
kl_loss = K.mean(kl_loss)  # Take the mean across the batch

# Total VAE loss: reconstruction loss + KL divergence loss
vae_loss_tot = reconstruction_loss + kl_loss


# Add the custom loss to the VAE model
vae.add_loss(vae_loss_tot)

# Compile the model
vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, clipvalue=1.0))

# %%
# Create a custom callback to print KL and reconstruction loss during training
class PrintLosses(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        # logs contains the losses from training
        reconstruction_loss_value = logs.get('loss')  # This is the VAE loss
        kl_loss_value = logs.get('val_loss')  # This is the validation loss
        
        # Print the losses
        print(f"Epoch {epoch+1}: Reconstruction Loss = {reconstruction_loss_value}, KL Divergence = {kl_loss_value}")

# %%
batch_size = 64
# Train the autoencoder
history1 = vae.fit(
    X_train,
    X_train,  # Input and output are the same for an autoencoder
    validation_data=(X_test, X_test),
    epochs=100,
    batch_size=batch_size,
    shuffle=True,
    verbose=2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True),
        PrintLosses()
    ]
)
# Out:
# Epoch 1/100
# Epoch 1: Reconstruction Loss = 1.5931098461151123, KL Divergence = 1.333364725112915
# 537/537 - 2s - loss: 1.5931 - val_loss: 1.3334 - 2s/epoch - 4ms/step
# Epoch 2/100
# Epoch 2: Reconstruction Loss = 1.2903410196304321, KL Divergence = 1.1913045644760132
# 537/537 - 1s - loss: 1.2903 - val_loss: 1.1913 - 1s/epoch - 2ms/step
# Epoch 3/100
# Epoch 3: Reconstruction Loss = 1.17662513256073, KL Divergence = 1.1272728443145752
# 537/537 - 1s - loss: 1.1766 - val_loss: 1.1273 - 1s/epoch - 2ms/step
# Epoch 4/100
# Epoch 4: Reconstruction Loss = 1.116416335105896, KL Divergence = 1.0845750570297241
# 537/537 - 1s - loss: 1.1164 - val_loss: 1.0846 - 1s/epoch - 2ms/step
# Epoch 5/100
# Epoch 5: Reconstruction Loss = 1.0782067775726318, KL Divergence = 1.0569289922714233
# 537/537 - 1s - loss: 1.0782 - val_loss: 1.0569 - 1s/epoch - 2ms/step
# Epoch 6/100
# Epoch 6: Reconstruction Loss = 1.051934003829956, KL Divergence = 1.0383647680282593
# 537/537 - 1s - loss: 1.0519 - val_loss: 1.0384 - 1s/epoch - 2ms/step
# Epoch 7/100
# Epoch 7: Reconstruction Loss = 1.0331932306289673, KL Divergence = 1.0271984338760376
# 537/537 - 1s - loss: 1.0332 - val_loss: 1.0272 - 1s/epoch - 2ms/step
# Epoch 8/100
# Epoch 8: Reconstruction Loss = 1.0235137939453125, KL Divergence = 1.0199803113937378
# 537/537 - 1s - loss: 1.0235 - val_loss: 1.0200 - 1s/epoch - 2ms/step
# Epoch 9/100
# Epoch 9: Reconstruction Loss = 1.0161277055740356, KL Divergence = 1.015451192855835
# 537/537 - 1s - loss: 1.0161 - val_loss: 1.0155 - 1s/epoch - 2ms/step
# Epoch 10/100
# Epoch 10: Reconstruction Loss = 1.0116732120513916, KL Divergence = 1.0122300386428833
# 537/537 - 1s - loss: 1.0117 - val_loss: 1.0122 - 1s/epoch - 2ms/step
# Epoch 11/100
# Epoch 11: Reconstruction Loss = 1.0089918375015259, KL Divergence = 1.0099515914916992
# 537/537 - 1s - loss: 1.0090 - val_loss: 1.0100 - 1s/epoch - 2ms/step
# Epoch 12/100
# Epoch 12: Reconstruction Loss = 1.006833791732788, KL Divergence = 1.0082851648330688
# 537/537 - 1s - loss: 1.0068 - val_loss: 1.0083 - 1s/epoch - 2ms/step
# Epoch 13/100
# Epoch 13: Reconstruction Loss = 1.0055110454559326, KL Divergence = 1.0072288513183594
# 537/537 - 1s - loss: 1.0055 - val_loss: 1.0072 - 1s/epoch - 2ms/step
# Epoch 14/100
# Epoch 14: Reconstruction Loss = 1.0046018362045288, KL Divergence = 1.0063735246658325
# 537/537 - 1s - loss: 1.0046 - val_loss: 1.0064 - 1s/epoch - 2ms/step
# Epoch 15/100
# Epoch 15: Reconstruction Loss = 1.004048228263855, KL Divergence = 1.0056347846984863
# 537/537 - 1s - loss: 1.0040 - val_loss: 1.0056 - 1s/epoch - 2ms/step
# Epoch 16/100
# Epoch 16: Reconstruction Loss = 1.003611445426941, KL Divergence = 1.0050694942474365
# 537/537 - 1s - loss: 1.0036 - val_loss: 1.0051 - 1s/epoch - 2ms/step
# Epoch 17/100
# Epoch 17: Reconstruction Loss = 1.0031944513320923, KL Divergence = 1.004542350769043
# 537/537 - 1s - loss: 1.0032 - val_loss: 1.0045 - 1s/epoch - 2ms/step
# Epoch 18/100
# Epoch 18: Reconstruction Loss = 1.0028074979782104, KL Divergence = 1.0039329528808594
# 537/537 - 1s - loss: 1.0028 - val_loss: 1.0039 - 1s/epoch - 2ms/step
# Epoch 19/100
# Epoch 19: Reconstruction Loss = 1.0024821758270264, KL Divergence = 1.003474235534668
# 537/537 - 1s - loss: 1.0025 - val_loss: 1.0035 - 1s/epoch - 2ms/step
# Epoch 20/100
# Epoch 20: Reconstruction Loss = 1.0021320581436157, KL Divergence = 1.0030972957611084
# 537/537 - 1s - loss: 1.0021 - val_loss: 1.0031 - 1s/epoch - 2ms/step
# Epoch 21/100
# Epoch 21: Reconstruction Loss = 1.0018526315689087, KL Divergence = 1.0026756525039673
# 537/537 - 1s - loss: 1.0019 - val_loss: 1.0027 - 1s/epoch - 2ms/step
# Epoch 22/100
# Epoch 22: Reconstruction Loss = 1.0016213655471802, KL Divergence = 1.002368688583374
# 537/537 - 1s - loss: 1.0016 - val_loss: 1.0024 - 1s/epoch - 2ms/step
# Epoch 23/100
# Epoch 23: Reconstruction Loss = 1.00141441822052, KL Divergence = 1.0020661354064941
# 537/537 - 1s - loss: 1.0014 - val_loss: 1.0021 - 1s/epoch - 2ms/step
# Epoch 24/100
# Epoch 24: Reconstruction Loss = 1.0012933015823364, KL Divergence = 1.001768946647644
# 537/537 - 1s - loss: 1.0013 - val_loss: 1.0018 - 1s/epoch - 2ms/step
# Epoch 25/100
# Epoch 25: Reconstruction Loss = 1.0011574029922485, KL Divergence = 1.0014828443527222
# 537/537 - 1s - loss: 1.0012 - val_loss: 1.0015 - 1s/epoch - 2ms/step
# Epoch 26/100
# Epoch 26: Reconstruction Loss = 1.0010087490081787, KL Divergence = 1.0011661052703857
# 537/537 - 1s - loss: 1.0010 - val_loss: 1.0012 - 1s/epoch - 2ms/step
# Epoch 27/100
# Epoch 27: Reconstruction Loss = 1.0008459091186523, KL Divergence = 1.0009266138076782
# 537/537 - 1s - loss: 1.0008 - val_loss: 1.0009 - 1s/epoch - 2ms/step
# Epoch 28/100
# Epoch 28: Reconstruction Loss = 1.000650405883789, KL Divergence = 1.000751256942749
# 537/537 - 1s - loss: 1.0007 - val_loss: 1.0008 - 1s/epoch - 2ms/step
# Epoch 29/100
# Epoch 29: Reconstruction Loss = 1.0005747079849243, KL Divergence = 1.0006228685379028
# 537/537 - 1s - loss: 1.0006 - val_loss: 1.0006 - 1s/epoch - 2ms/step
# Epoch 30/100
# Epoch 30: Reconstruction Loss = 1.0004534721374512, KL Divergence = 1.000471591949463
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0005 - 1s/epoch - 2ms/step
# Epoch 31/100
# Epoch 31: Reconstruction Loss = 1.0003913640975952, KL Divergence = 1.0003793239593506
# 537/537 - 1s - loss: 1.0004 - val_loss: 1.0004 - 1s/epoch - 2ms/step
# Epoch 32/100
# Epoch 32: Reconstruction Loss = 1.0002875328063965, KL Divergence = 1.000240445137024
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0002 - 1s/epoch - 2ms/step
# Epoch 33/100
# Epoch 33: Reconstruction Loss = 1.0002282857894897, KL Divergence = 1.000183343887329
# 537/537 - 1s - loss: 1.0002 - val_loss: 1.0002 - 1s/epoch - 2ms/step
# Epoch 34/100
# Epoch 34: Reconstruction Loss = 1.000296711921692, KL Divergence = 1.000169038772583
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0002 - 1s/epoch - 2ms/step
# Epoch 35/100
# Epoch 35: Reconstruction Loss = 1.0001752376556396, KL Divergence = 1.0001229047775269
# 537/537 - 1s - loss: 1.0002 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 36/100
# Epoch 36: Reconstruction Loss = 1.0001832246780396, KL Divergence = 1.0000859498977661
# 537/537 - 1s - loss: 1.0002 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 37/100
# Epoch 37: Reconstruction Loss = 1.0002167224884033, KL Divergence = 1.00006902217865
# 537/537 - 1s - loss: 1.0002 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 38/100
# Epoch 38: Reconstruction Loss = 1.0001364946365356, KL Divergence = 1.0000410079956055
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 39/100
# Epoch 39: Reconstruction Loss = 1.0001171827316284, KL Divergence = 1.00005042552948
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 40/100
# Epoch 40: Reconstruction Loss = 1.0000953674316406, KL Divergence = 1.0000251531600952
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 41/100
# Epoch 41: Reconstruction Loss = 1.0000828504562378, KL Divergence = 1.0000319480895996
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 42/100
# Epoch 42: Reconstruction Loss = 1.0000756978988647, KL Divergence = 1.0000534057617188
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 43/100
# Epoch 43: Reconstruction Loss = 1.0001009702682495, KL Divergence = 1.0000232458114624
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 44/100
# Epoch 44: Reconstruction Loss = 1.000076413154602, KL Divergence = 1.0000348091125488
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 45/100
# Epoch 45: Reconstruction Loss = 1.0000684261322021, KL Divergence = 1.0000343322753906
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 46/100
# Epoch 46: Reconstruction Loss = 1.0000323057174683, KL Divergence = 1.0000723600387573
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 47/100
# Epoch 47: Reconstruction Loss = 1.0000569820404053, KL Divergence = 1.0000468492507935
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 48/100
# Epoch 48: Reconstruction Loss = 1.0000627040863037, KL Divergence = 1.0000410079956055
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 49/100
# Epoch 49: Reconstruction Loss = 1.0000520944595337, KL Divergence = 1.000035285949707
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 50/100
# Epoch 50: Reconstruction Loss = 1.0000723600387573, KL Divergence = 1.000038743019104
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 51/100
# Epoch 51: Reconstruction Loss = 1.0000618696212769, KL Divergence = 1.000030279159546
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 52/100
# Epoch 52: Reconstruction Loss = 1.000069260597229, KL Divergence = 1.0000263452529907
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 53/100
# Epoch 53: Reconstruction Loss = 1.0000771284103394, KL Divergence = 1.000020980834961
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 54/100
# Epoch 54: Reconstruction Loss = 1.00003981590271, KL Divergence = 1.0000150203704834
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 55/100
# Epoch 55: Reconstruction Loss = 1.0000536441802979, KL Divergence = 1.00001859664917
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 56/100
# Epoch 56: Reconstruction Loss = 1.000043511390686, KL Divergence = 1.0000216960906982
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 57/100
# Epoch 57: Reconstruction Loss = 1.0000537633895874, KL Divergence = 1.0000295639038086
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 58/100
# Epoch 58: Reconstruction Loss = 1.0000394582748413, KL Divergence = 1.0000114440917969
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 59/100
# Epoch 59: Reconstruction Loss = 1.0000356435775757, KL Divergence = 1.0000237226486206
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 60/100
# Epoch 60: Reconstruction Loss = 1.0000401735305786, KL Divergence = 1.000013828277588
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 61/100
# Epoch 61: Reconstruction Loss = 1.0000214576721191, KL Divergence = 1.0000253915786743
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 62/100
# Epoch 62: Reconstruction Loss = 1.0000361204147339, KL Divergence = 1.000022053718567
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 63/100
# Epoch 63: Reconstruction Loss = 1.0000286102294922, KL Divergence = 1.000015139579773
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 64/100
# Epoch 64: Reconstruction Loss = 1.0000216960906982, KL Divergence = 1.0000159740447998
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 65/100
# Epoch 65: Reconstruction Loss = 1.0000278949737549, KL Divergence = 1.0000238418579102
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 66/100
# Epoch 66: Reconstruction Loss = 1.0000348091125488, KL Divergence = 1.0000158548355103
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 67/100
# Epoch 67: Reconstruction Loss = 1.000028133392334, KL Divergence = 1.0000113248825073
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 68/100
# Epoch 68: Reconstruction Loss = 1.000030517578125, KL Divergence = 1.0000172853469849
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 69/100
# Epoch 69: Reconstruction Loss = 1.0000165700912476, KL Divergence = 1.0000171661376953
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 70/100
# Epoch 70: Reconstruction Loss = 1.0000218152999878, KL Divergence = 1.0000076293945312
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 71/100
# Epoch 71: Reconstruction Loss = 1.00001859664917, KL Divergence = 1.000014066696167
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 72/100
# Epoch 72: Reconstruction Loss = 1.0000100135803223, KL Divergence = 1.000009298324585
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 73/100
# Epoch 73: Reconstruction Loss = 1.0000196695327759, KL Divergence = 1.0000109672546387
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 74/100
# Epoch 74: Reconstruction Loss = 1.000012755393982, KL Divergence = 1.0000137090682983
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 75/100
# Epoch 75: Reconstruction Loss = 1.0000158548355103, KL Divergence = 1.0000226497650146
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 76/100
# Epoch 76: Reconstruction Loss = 1.000016450881958, KL Divergence = 1.000010371208191
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 77/100
# Epoch 77: Reconstruction Loss = 1.0000083446502686, KL Divergence = 1.0000137090682983
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 78/100
# Epoch 78: Reconstruction Loss = 1.0000073909759521, KL Divergence = 1.000012993812561
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 79/100
# Epoch 79: Reconstruction Loss = 1.000016450881958, KL Divergence = 1.0000090599060059
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 80/100
# Epoch 80: Reconstruction Loss = 1.0000056028366089, KL Divergence = 1.0000120401382446
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 81/100
# Epoch 81: Reconstruction Loss = 1.000005841255188, KL Divergence = 1.0000132322311401
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 82/100
# Epoch 82: Reconstruction Loss = 1.0000070333480835, KL Divergence = 1.0000107288360596
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 83/100
# Epoch 83: Reconstruction Loss = 1.0000067949295044, KL Divergence = 1.0000122785568237
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 84/100
# Epoch 84: Reconstruction Loss = 1.0000213384628296, KL Divergence = 1.000006079673767
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 85/100
# Epoch 85: Reconstruction Loss = 1.0000085830688477, KL Divergence = 1.000008463859558
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 86/100
# Epoch 86: Reconstruction Loss = 1.000011682510376, KL Divergence = 1.0000097751617432
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 87/100
# Epoch 87: Reconstruction Loss = 1.0000101327896118, KL Divergence = 1.000009536743164
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 88/100
# Epoch 88: Reconstruction Loss = 1.0000118017196655, KL Divergence = 1.0000042915344238
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 89/100
# Epoch 89: Reconstruction Loss = 1.0000097751617432, KL Divergence = 1.0000115633010864
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 90/100
# Epoch 90: Reconstruction Loss = 1.0000081062316895, KL Divergence = 1.0000075101852417
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 91/100
# Epoch 91: Reconstruction Loss = 1.0000040531158447, KL Divergence = 1.0000110864639282
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 92/100
# Epoch 92: Reconstruction Loss = 1.000012993812561, KL Divergence = 1.0000070333480835
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 93/100
# Epoch 93: Reconstruction Loss = 1.0000109672546387, KL Divergence = 1.0000077486038208
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 94/100
# Epoch 94: Reconstruction Loss = 1.0000014305114746, KL Divergence = 1.000015139579773
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 95/100
# Epoch 95: Reconstruction Loss = 1.0000076293945312, KL Divergence = 1.0000097751617432
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 96/100
# Epoch 96: Reconstruction Loss = 1.0000073909759521, KL Divergence = 1.0000051259994507
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 97/100
# Epoch 97: Reconstruction Loss = 1.0000113248825073, KL Divergence = 1.0000041723251343
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 98/100
# Epoch 98: Reconstruction Loss = 1.0000102519989014, KL Divergence = 1.000009298324585
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 99/100
# Epoch 99: Reconstruction Loss = 1.0000067949295044, KL Divergence = 1.0000128746032715
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 100/100
# Epoch 100: Reconstruction Loss = 1.0000109672546387, KL Divergence = 1.0000078678131104
# 537/537 - 1s - loss: 1.0000 - val_loss: 1.0000 - 1s/epoch - 2ms/step

# %%
vae.save_weights('vae_mlp.h5')

# %%
# Plot training and validation loss
plt.plot(history1.history['loss'], label='Training Loss')
plt.plot(history1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('VAE Loss')
plt.legend()
plt.title('Variational Autoencoder Training Performance')
plt.show()

# %% [markdown]
# AFter 10 epochs the model accuracy does not particularly improve. There is a lareg step around 15 epochs where the model has likely fallen into a depp well of the loss function manifold.

# %%
import numpy as np

# Get model predictions (reconstructed data)
reconstructions1 = vae.predict(X_test)

# Compute reconstruction loss (MSE for each sample)
reconstruction_loss = np.mean(np.square(X_test - reconstructions1), axis=1)

# Print sample reconstruction losses
print("Reconstruction Loss (first 10 samples):", reconstruction_loss[:10])
# Out:
# 461/461 [==============================] - 1s 1ms/step
# Reconstruction Loss (first 10 samples): [0.2177028  0.32153029 0.10711622 0.05130712 0.79595273 0.06238724
#  0.11953814 0.18089791 0.25008235 0.06962566]

# %%
# Select the 95th percentile as the anomaly threshold
threshold = np.percentile(reconstruction_loss, 95)

print(f"Selected Threshold: {threshold}")
# Out:
# Selected Threshold: 3.8777505868441966

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.histplot(reconstruction_loss, bins=50, kde=True, color='blue')
plt.axvline(threshold, color='red', linestyle='dashed', linewidth=2, label=f'Threshold: {threshold:.4f}')
plt.xlabel("Reconstruction Loss")
plt.ylabel("Frequency")
plt.title("Distribution of Reconstruction Loss")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\noona\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Predict anomalies: If reconstruction loss > threshold, classify as anomaly (1), else normal (0)
y_pred = (reconstruction_loss > threshold).astype(int)

# Print number of anomalies detected
print(f"Number of anomalies detected: {np.sum(y_pred)}")
# Out:
# Number of anomalies detected: 737

# %%
from sklearn.metrics import roc_curve, auc

# Get actual anomaly labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual labels

# Compute ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_true, reconstruction_loss)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='dashed')  # Random chance line
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("ROC Curve for VAE Anomaly Detection")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Transform the training data into the latent space
z_mean, z_log_var, z = encoder.predict(X_train)  # Ensure encoder has 3 outputs

latent_space = z_mean  # Use z_mean for visualization

# Ensure Y_train is a NumPy array and flattened
Y_train_array = np.array(Y_train).flatten()  # Convert to a 1D NumPy array if it's a DataFrame or Series

# Define colors: Normal samples (blue), Anomalies (red)
colors = np.array(['blue'] * len(Y_train_array))  # Default all to blue
colors[Y_train_array == 1] = 'red'  # Set anomalies to red

# Plot the latent space with different colors for anomalies
plt.figure(figsize=(8, 6))
plt.scatter(latent_space[:, 0], latent_space[:, 1], c=colors, alpha=0.5)
plt.xlabel('Latent Variable 1')
plt.ylabel('Latent Variable 2')
plt.title('Latent Space Visualization')
plt.grid(True)

# Add legend
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Normal', markersize=8, markerfacecolor='blue'),
                   Line2D([0], [0], marker='o', color='w', label='Anomaly', markersize=8, markerfacecolor='red')]
plt.legend(handles=legend_elements)

plt.show()
# Out:
# 1074/1074 [==============================] - 1s 1ms/step

# %% [markdown]
# This cluster is more centred around the (0,0) as expected as we are restricting our latent space to a normal distribution.

# %% [markdown]
# Different plots for each run as we are sampling from ditribution.

# %%
# Compute Youden's J statistic
youden_j = tpr - fpr
best_index = np.argmax(youden_j)  # Index of max Youden's J
best_threshold = thresholds[best_index]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Step 1: Get model predictions (Reconstruction Errors)
reconstructions = vae.predict(X_test)  # X_test is the test data
reconstruction_errors = np.mean(np.square(X_test - reconstructions), axis=1)

# Step 2: Set an anomaly detection threshold (e.g., 95th percentile)
threshold = np.percentile(reconstruction_errors, 95)

# Step 3: Predict anomalies based on threshold
y_pred = (reconstruction_errors > threshold).astype(int)  # 1 = Anomaly, 0 = Normal
y_pred = (reconstruction_errors > best_threshold).astype(int)  # 1 = Anomaly, 0 = Normal

# Step 4: Get actual labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual anomaly labels

# Step 5: Compute Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Step 6: Plot Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Step 7: Print Classification Report
print(classification_report(y_true, y_pred))
# Out:
# 461/461 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13677
#            1       0.97      0.94      0.95      1053
#
#     accuracy                           0.99     14730
#    macro avg       0.98      0.97      0.98     14730
# weighted avg       0.99      0.99      0.99     14730

# %% [markdown]
# ## Reflection
#
# There are no specific marks allocated for a reflection. However due consideration will be given if pertinent comments or valuable insights are made.

# %% [markdown]
# This task required building an autoencoder and variational autoencoder for data in order to predict anomalies.
#
# Initial data nanalysis showed high corrrelations between particular variables and anomalies which meant dimensional reduction  ould likely be successful.
#
# The first issue I had was data snooping. I applied the scaler function before separating train and tets data. The scaler function relaly helps the autoencoder to train.I ensured equal number of anomalies in both train and test sets. This ws recommended by one of my peers.
#
# ### Autoencoder
# The layers between the latent space had reducing number of dimensions. I inially had too high of numbers here which one of my peers spotted.
#
# Th latent space dhiwed a cluster with no strcit shape.
#
# Anomalies were considered as thos with reconstruction errors greater than the 95th percentile. This was the threshold set. The precision was quite good but the recall for anomalies was not. The ROC cureve with the Youden index was then used to find the best threshold and proved to have better results.
#
# ### Variational autoencoder:
# For the variational autoencoder a similar arhitecture was used only that the latent spae was restricted to a normal distribution with means and standard deviations.
#
# This model performed well. The latent space showed more structure also closer to a normal distribution.
