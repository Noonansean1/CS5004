# %% [markdown]
# # E-tivity 1 (27/01/25 - 09/02/25)
#
# * Sean Noonan
#
# * 23300159

# %% [markdown]
# ## Anomaly Detection
#
# ### Context
# We have a mystery dataset. There are 9 explanatory variables and one response variable. The response variable is the last column and indicates if the sample is anomalous (=1, valid =0). The dataset is provided "data.csv".
#
# Of course in this case we could use supervised learning to generate a model and detect anomalies in new data. However the focus is on autoencoders, anomaly detection is just one of the potential uses for autoencoders.
#
# So we are going to pretend that we do not know which data are anomalous but we do know that the anomaly rate is small. Use an autoencoder to detect anomalies in the data. The correctness of the model can of course be checked.

# %% [markdown]
# ### Guidelines
#
# The e-tivity is split into four tasks. The first three are "group" excersises, in that you post the solutions to Tasks 1-3 to a site. This will allow the members of your group to send you feedback (via the forums) so you can improve your submission. The final task is an individual task and together with the other tasks, should be uploaded to the Group Locker.
#
# Marks will be deducted if task 4 is uploaded in contravention of instructions. Also if the the final submission is not a single notebook with tasks 1-4 and with correct identification or filename.
#
# Grading guidelines: the scores for each task are additive. Below is a link to the E-tivity rubrics.
#
# https://learn.ul.ie/d2l/lp/rubrics/preview.d2l?ou=49284&rubricId=2620&originTool=quicklinks

# %% [markdown]
# ## Problem
#
# If you train even a modest feed forward network via supervised learning you can get extremely good recall and precision, despite the unbalanced dataset. However in this e-tivity you will determining the anomalies by using an autoencoder. That is you will **not** be using the Anom flag to guide the training.
#
# The mystery dataset is available from Brightspace, download the csv file and use it as the input data.
#
# ### Tasks 1-3 (complete by Sunday 02/02/25)
#
# The initial implementation of the tasks are to be uploaded to the locker on which the other group members can comment. The forum activity will form part of the overall mark for the e-tivity.

# %% [markdown]
# **Task 1: data preprocessing**
#
# Explain any preprocessing steps you take and also how you have selected the training and test sets. Remember we do not know which samples are anomalous only that there are a small number of them compared to the total sample size.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data.csv")

# %% [markdown]
# ## Quick peep at data

# %%
# Lets have a look at the data
df.head()
# Out:
#    V1  V2  V3  V4  V5  V6  V7  V8  V9  Anom
# 0  50  21  77   0  28   0  27  48  22     1
# 1  53   0  82   0  52  -5  29  30   2     0
# 2  37   0  76   0  28  18  40  48   8     0
# 3  37   0  79   0  34 -26  43  46   2     0
# 4  85   0  88  -4   6   1   3  83  80     1

# %%
print(df.count())
# Out:
# V1      49097
# V2      49097
# V3      49097
# V4      49097
# V5      49097
# V6      49097
# V7      49097
# V8      49097
# V9      49097
# Anom    49097
# dtype: int64

# %%
# Print statistical summary for all numerical attributes
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  49097.000000  49097.000000  49097.000000  49097.000000  49097.000000
# mean      46.932399     -0.063955     85.123124      0.213231     36.871784
# std       12.875159     84.674481      8.877517     37.579171     19.963113
# min       27.000000  -4821.000000     21.000000  -3939.000000   -188.000000
# 25%       37.000000      0.000000     79.000000      0.000000     30.000000
# 50%       44.000000      0.000000     83.000000      0.000000     42.000000
# 75%       50.000000      0.000000     88.000000      0.000000     46.000000
# max      126.000000   5075.000000    149.000000   3830.000000    436.000000
#
#                  V6            V7            V8            V9          Anom
# count  49097.000000  49097.000000  49097.000000  49097.000000  49097.000000
# mean       2.160030     38.200725     48.288592     10.261930      0.071511
# std      218.324964     13.446306     20.572064     23.751024      0.257680
# min   -26739.000000    -48.000000   -353.000000   -356.000000      0.000000
# 25%       -4.000000     33.000000     35.000000      0.000000      0.000000
# 50%        0.000000     39.000000     41.000000      2.000000      0.000000
# 75%        5.000000     43.000000     55.000000      6.000000      0.000000
# max    15164.000000    105.000000    270.000000    266.000000      1.000000

# %% [markdown]
# There is a wide range of values here. Scaling will be useful in ppreprocessing. There are 50k samples and 9 features. This is plenty of datapoints.

# %%
numerical_columns = df.select_dtypes(include=['number']).columns
missing_numerical = df[numerical_columns].isnull().sum()

print("Missing values in numerical variables:")
print(missing_numerical)
# Out:
# Missing values in numerical variables:
# V1      0
# V2      0
# V3      0
# V4      0
# V5      0
# V6      0
# V7      0
# V8      0
# V9      0
# Anom    0
# dtype: int64

# %%
# Count rows where the 'Anom' column is equal to 1
num_anomalies = df[df['Anom'] == 1].shape[0]

print(f"Number of rows with 'Anom' = 1: {num_anomalies}")
# Out:
# Number of rows with 'Anom' = 1: 3511

# %% [markdown]
# So we have 49k records and 3.5 k anomalies

# %%
3511/49097
# Out:
# 0.0715114976475141

# %% [markdown]
# We have a 7% anomally rate

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = df.corr()

# Display the matrix as a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Add title
plt.title("Correlation Matrix")

# Show the plot
plt.show()

# %% [markdown]
# There are a lot of strong correlations visible

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42)

# Print sizes to verify
print(f"Training set size: {len(df_train)}")
print(f"Testing set size: {len(df_test)}")
# Out:
# Training set size: 34367
# Testing set size: 14730

# %%
from sklearn.model_selection import train_test_split

# Assuming df has the column 'ANOM' where anomalies are labeled as 1 and normal data as 0
X = df.drop('Anom', axis=1)  # All columns except the target column 'ANOM'
y = df['Anom']  # The target variable that contains anomalies (1) and normal (0)

# Stratified split to ensure same proportion of anomalies in train and test
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42, stratify=y)

# Check the proportions in the split
print("Train anomaly distribution:\n", df_train['Anom'].value_counts(normalize=True))
print("Test anomaly distribution:\n", df_test['Anom'].value_counts(normalize=True))
# Out:
# Train anomaly distribution:
#  Anom
# 0    0.928478
# 1    0.071522
# Name: proportion, dtype: float64
# Test anomaly distribution:
#  Anom
# 0    0.928513
# 1    0.071487
# Name: proportion, dtype: float64

# %% [markdown]
# The training and test set must be split before any preprocessing. This split should ensure equal number sof anomalies in both.

# %% [markdown]
# Set up the labelled and unlabelled data

# %%
X_train = df_train.drop("Anom", axis=1)
Y_train = df_train[['Anom']].copy()
X_test = df_test.drop("Anom", axis=1)
Y_test = df_test[['Anom']].copy()

# %% [markdown]
# **Task 2: model generation and training**
#
# Generate a suitable autoencoder model, the only restriction is that there should be only 2 latent variables. Train the model to a satistifactory result. Be aware that it will be much harder to achieve the sort of result you can get from a supervised learning model.
#
# **Hint**: it should not take longer than a 1000 epochs to train. However it may be difficult to train. Use different optimizers, topologies and/or weight initialisations to get convergence. Remember that achieving a perfect error means that the model will also be good at reconstructing anomalies.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# Load the module we need
# Note that we are import the Keras backend, which is assumed to be Tensorflow
from tensorflow.keras.layers import UpSampling2D, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras import backend as K


from tensorflow.keras.layers import Lambda
from tensorflow.keras.losses import mean_squared_error, binary_crossentropy, mse, KLDivergence
from tensorflow.keras.utils import plot_model

import tensorflow as tf
import os
# Out:
# WARNING:tensorflow:From C:\Users\noona\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# Example dataset (replace `df_unlabelled` with your own data)
# data_train = X_train.values

# Normalize the data to [0, 1], need toi do on test and train separately to void data snooping
scaler = MinMaxScaler()
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# data_test = X_test.values

X_test = scaler.fit_transform(X_test)

# Dimensions of the input data
input_dim = X_train.shape[1]
print(input_dim)
# Out:
# 9

# %%
# pip install pydot

# %%
# pip install graphviz

# %%
# Define the Encoder, inputs are the MNIST 28x28 greyscale images 
inputs = layers.Input(shape=(input_dim,))
x = layers.Dense(6, activation='relu', kernel_initializer='he_normal')(inputs)
x = layers.Dense(4, activation='relu', kernel_initializer='he_normal')(x)
latent = layers.Dense(2, activation='linear', name='latent_space')(x)  # 2 latent variables

encoded = Model(inputs,latent,name='encoded')
encoded.summary()
# plot_model(encoded, to_file='AE_encoded_etiv.png', show_shapes=True)            

# Latent space is a 5 dimensional vector space

# This is the decoder, it take the 5 dim latent vector and generates a 28x28 image
# lats = Input(shape=(2,),name='latent')
# Decoder
latent_inputs = layers.Input(shape=(2,))
x = layers.Dense(4, activation='relu', kernel_initializer='he_normal')(latent_inputs)
x = layers.Dense(6, activation='relu', kernel_initializer='he_normal')(x)
outputs = layers.Dense(input_dim, activation='sigmoid')(x)  # Sigmoid to ensure output in [0, 1]

decoded = Model(latent_inputs,outputs,name='decoded')
decoded.summary()
# plot_model(decoded, to_file='AE_decoded_etiv.png', show_shapes=True)     

# The autoencoder takes the image as input encodes it, then decodes it
rec = decoded(encoded(inputs))
autoencoder = Model(inputs,rec,name="AE")

reconstructions = autoencoder.predict(X_test)
reconstruction_loss = np.mean(np.square(reconstructions - X_test), axis=1)
# autoencoder.add_loss(lambda: reconstruction_loss) 
autoencoder.summary()
# Out:
# WARNING:tensorflow:From C:\Users\noona\anaconda3\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "encoded"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 9)]               0
#
#  dense (Dense)               (None, 6)                 60
#
#  dense_1 (Dense)             (None, 4)                 28
#
#  latent_space (Dense)        (None, 2)                 10
#
# =================================================================
# Total params: 98 (392.00 Byte)
# Trainable params: 98 (392.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "decoded"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_2 (Dense)             (None, 4)                 12
#
#  dense_3 (Dense)             (None, 6)                 30
#
#  dense_4 (Dense)             (None, 9)                 63
#
# =================================================================
# Total params: 105 (420.00 Byte)
# Trainable params: 105 (420.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 461/461 [==============================] - 1s 1ms/step
# Model: "AE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 9)]               0
#
#  encoded (Functional)        (None, 2)                 98
#
#  decoded (Functional)        (None, 9)                 105
#
# =================================================================
# Total params: 203 (812.00 Byte)
# Trainable params: 203 (812.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse')

# %%
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mae')

# %%
# Train the autoencoder
history = autoencoder.fit(
    X_train,
    X_train,  # Input and output are the same for an autoencoder
    validation_data=(X_test, X_test),
    epochs=150,
    batch_size=32,
    shuffle=True,
    verbose=2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    ]
)
# Out:
# Epoch 1/150
# WARNING:tensorflow:From C:\Users\noona\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1074/1074 - 3s - loss: 0.4660 - val_loss: 0.3990 - 3s/epoch - 3ms/step
# Epoch 2/150
# 1074/1074 - 2s - loss: 0.3854 - val_loss: 0.3795 - 2s/epoch - 2ms/step
# Epoch 3/150
# 1074/1074 - 2s - loss: 0.3673 - val_loss: 0.3629 - 2s/epoch - 2ms/step
# Epoch 4/150
# 1074/1074 - 2s - loss: 0.3582 - val_loss: 0.3589 - 2s/epoch - 2ms/step
# Epoch 5/150
# 1074/1074 - 2s - loss: 0.3553 - val_loss: 0.3574 - 2s/epoch - 2ms/step
# Epoch 6/150
# 1074/1074 - 2s - loss: 0.3542 - val_loss: 0.3566 - 2s/epoch - 2ms/step
# Epoch 7/150
# 1074/1074 - 2s - loss: 0.3535 - val_loss: 0.3556 - 2s/epoch - 2ms/step
# Epoch 8/150
# 1074/1074 - 2s - loss: 0.3530 - val_loss: 0.3552 - 2s/epoch - 2ms/step
# Epoch 9/150
# 1074/1074 - 2s - loss: 0.3525 - val_loss: 0.3547 - 2s/epoch - 2ms/step
# Epoch 10/150
# 1074/1074 - 2s - loss: 0.3521 - val_loss: 0.3544 - 2s/epoch - 2ms/step
# Epoch 11/150
# 1074/1074 - 2s - loss: 0.3518 - val_loss: 0.3543 - 2s/epoch - 2ms/step
# Epoch 12/150
# 1074/1074 - 2s - loss: 0.3514 - val_loss: 0.3536 - 2s/epoch - 2ms/step
# Epoch 13/150
# 1074/1074 - 2s - loss: 0.3512 - val_loss: 0.3535 - 2s/epoch - 2ms/step
# Epoch 14/150
# 1074/1074 - 2s - loss: 0.3509 - val_loss: 0.3531 - 2s/epoch - 2ms/step
# Epoch 15/150
# 1074/1074 - 2s - loss: 0.3508 - val_loss: 0.3535 - 2s/epoch - 2ms/step
# Epoch 16/150
# 1074/1074 - 2s - loss: 0.3506 - val_loss: 0.3530 - 2s/epoch - 2ms/step
# Epoch 17/150
# 1074/1074 - 2s - loss: 0.3505 - val_loss: 0.3527 - 2s/epoch - 2ms/step
# Epoch 18/150
# 1074/1074 - 2s - loss: 0.3504 - val_loss: 0.3526 - 2s/epoch - 2ms/step
# Epoch 19/150
# 1074/1074 - 2s - loss: 0.3503 - val_loss: 0.3531 - 2s/epoch - 2ms/step
# Epoch 20/150
# 1074/1074 - 2s - loss: 0.3502 - val_loss: 0.3528 - 2s/epoch - 2ms/step
# Epoch 21/150
# 1074/1074 - 2s - loss: 0.3501 - val_loss: 0.3526 - 2s/epoch - 2ms/step
# Epoch 22/150
# 1074/1074 - 2s - loss: 0.3500 - val_loss: 0.3526 - 2s/epoch - 2ms/step
# Epoch 23/150
# 1074/1074 - 2s - loss: 0.3499 - val_loss: 0.3522 - 2s/epoch - 2ms/step
# Epoch 24/150
# 1074/1074 - 2s - loss: 0.3498 - val_loss: 0.3525 - 2s/epoch - 2ms/step
# Epoch 25/150
# 1074/1074 - 2s - loss: 0.3497 - val_loss: 0.3522 - 2s/epoch - 2ms/step
# Epoch 26/150
# 1074/1074 - 2s - loss: 0.3497 - val_loss: 0.3522 - 2s/epoch - 2ms/step
# Epoch 27/150
# 1074/1074 - 2s - loss: 0.3496 - val_loss: 0.3520 - 2s/epoch - 2ms/step
# Epoch 28/150
# 1074/1074 - 3s - loss: 0.3495 - val_loss: 0.3521 - 3s/epoch - 2ms/step
# Epoch 29/150
# 1074/1074 - 2s - loss: 0.3495 - val_loss: 0.3519 - 2s/epoch - 2ms/step
# Epoch 30/150
# 1074/1074 - 2s - loss: 0.3494 - val_loss: 0.3518 - 2s/epoch - 2ms/step
# Epoch 31/150
# 1074/1074 - 2s - loss: 0.3494 - val_loss: 0.3518 - 2s/epoch - 2ms/step
# Epoch 32/150
# 1074/1074 - 2s - loss: 0.3494 - val_loss: 0.3521 - 2s/epoch - 2ms/step
# Epoch 33/150
# 1074/1074 - 2s - loss: 0.3493 - val_loss: 0.3521 - 2s/epoch - 2ms/step
# Epoch 34/150
# 1074/1074 - 2s - loss: 0.3492 - val_loss: 0.3515 - 2s/epoch - 2ms/step
# Epoch 35/150
# 1074/1074 - 2s - loss: 0.3492 - val_loss: 0.3518 - 2s/epoch - 2ms/step
# Epoch 36/150
# 1074/1074 - 2s - loss: 0.3492 - val_loss: 0.3517 - 2s/epoch - 2ms/step
# Epoch 37/150
# 1074/1074 - 2s - loss: 0.3491 - val_loss: 0.3515 - 2s/epoch - 2ms/step
# Epoch 38/150
# 1074/1074 - 2s - loss: 0.3491 - val_loss: 0.3514 - 2s/epoch - 2ms/step
# Epoch 39/150
# 1074/1074 - 2s - loss: 0.3490 - val_loss: 0.3515 - 2s/epoch - 2ms/step
# Epoch 40/150
# 1074/1074 - 2s - loss: 0.3490 - val_loss: 0.3515 - 2s/epoch - 2ms/step
# Epoch 41/150
# 1074/1074 - 2s - loss: 0.3490 - val_loss: 0.3514 - 2s/epoch - 2ms/step
# Epoch 42/150
# 1074/1074 - 2s - loss: 0.3490 - val_loss: 0.3514 - 2s/epoch - 2ms/step
# Epoch 43/150
# 1074/1074 - 2s - loss: 0.3489 - val_loss: 0.3515 - 2s/epoch - 2ms/step
# Epoch 44/150
# 1074/1074 - 2s - loss: 0.3489 - val_loss: 0.3513 - 2s/epoch - 2ms/step
# Epoch 45/150
# 1074/1074 - 2s - loss: 0.3489 - val_loss: 0.3517 - 2s/epoch - 2ms/step
# Epoch 46/150
# 1074/1074 - 2s - loss: 0.3489 - val_loss: 0.3515 - 2s/epoch - 2ms/step
# Epoch 47/150
# 1074/1074 - 2s - loss: 0.3488 - val_loss: 0.3523 - 2s/epoch - 2ms/step
# Epoch 48/150
# 1074/1074 - 2s - loss: 0.3488 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 49/150
# 1074/1074 - 2s - loss: 0.3488 - val_loss: 0.3514 - 2s/epoch - 2ms/step
# Epoch 50/150
# 1074/1074 - 2s - loss: 0.3488 - val_loss: 0.3514 - 2s/epoch - 2ms/step
# Epoch 51/150
# 1074/1074 - 2s - loss: 0.3488 - val_loss: 0.3514 - 2s/epoch - 2ms/step
# Epoch 52/150
# 1074/1074 - 2s - loss: 0.3488 - val_loss: 0.3515 - 2s/epoch - 2ms/step
# Epoch 53/150
# 1074/1074 - 2s - loss: 0.3488 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 54/150
# 1074/1074 - 2s - loss: 0.3487 - val_loss: 0.3514 - 2s/epoch - 2ms/step
# Epoch 55/150
# 1074/1074 - 2s - loss: 0.3488 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 56/150
# 1074/1074 - 2s - loss: 0.3487 - val_loss: 0.3512 - 2s/epoch - 2ms/step
# Epoch 57/150
# 1074/1074 - 2s - loss: 0.3487 - val_loss: 0.3522 - 2s/epoch - 2ms/step
# Epoch 58/150
# 1074/1074 - 2s - loss: 0.3487 - val_loss: 0.3512 - 2s/epoch - 2ms/step
# Epoch 59/150
# 1074/1074 - 2s - loss: 0.3487 - val_loss: 0.3515 - 2s/epoch - 2ms/step
# Epoch 60/150
# 1074/1074 - 2s - loss: 0.3487 - val_loss: 0.3515 - 2s/epoch - 2ms/step
# Epoch 61/150
# 1074/1074 - 2s - loss: 0.3487 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 62/150
# 1074/1074 - 2s - loss: 0.3486 - val_loss: 0.3512 - 2s/epoch - 2ms/step
# Epoch 63/150
# 1074/1074 - 2s - loss: 0.3487 - val_loss: 0.3516 - 2s/epoch - 2ms/step
# Epoch 64/150
# 1074/1074 - 2s - loss: 0.3486 - val_loss: 0.3516 - 2s/epoch - 2ms/step
# Epoch 65/150
# 1074/1074 - 2s - loss: 0.3486 - val_loss: 0.3520 - 2s/epoch - 2ms/step
# Epoch 66/150
# 1074/1074 - 2s - loss: 0.3486 - val_loss: 0.3512 - 2s/epoch - 2ms/step
# Epoch 67/150
# 1074/1074 - 2s - loss: 0.3486 - val_loss: 0.3510 - 2s/epoch - 2ms/step
# Epoch 68/150
# 1074/1074 - 2s - loss: 0.3486 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 69/150
# 1074/1074 - 2s - loss: 0.3486 - val_loss: 0.3510 - 2s/epoch - 2ms/step
# Epoch 70/150
# 1074/1074 - 2s - loss: 0.3486 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 71/150
# 1074/1074 - 2s - loss: 0.3485 - val_loss: 0.3509 - 2s/epoch - 2ms/step
# Epoch 72/150
# 1074/1074 - 2s - loss: 0.3485 - val_loss: 0.3513 - 2s/epoch - 2ms/step
# Epoch 73/150
# 1074/1074 - 2s - loss: 0.3484 - val_loss: 0.3510 - 2s/epoch - 2ms/step
# Epoch 74/150
# 1074/1074 - 2s - loss: 0.3484 - val_loss: 0.3508 - 2s/epoch - 2ms/step
# Epoch 75/150
# 1074/1074 - 2s - loss: 0.3483 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 76/150
# 1074/1074 - 2s - loss: 0.3483 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 77/150
# 1074/1074 - 2s - loss: 0.3483 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 78/150
# 1074/1074 - 2s - loss: 0.3483 - val_loss: 0.3506 - 2s/epoch - 2ms/step
# Epoch 79/150
# 1074/1074 - 2s - loss: 0.3483 - val_loss: 0.3506 - 2s/epoch - 2ms/step
# Epoch 80/150
# 1074/1074 - 2s - loss: 0.3483 - val_loss: 0.3510 - 2s/epoch - 2ms/step
# Epoch 81/150
# 1074/1074 - 2s - loss: 0.3482 - val_loss: 0.3509 - 2s/epoch - 2ms/step
# Epoch 82/150
# 1074/1074 - 2s - loss: 0.3483 - val_loss: 0.3512 - 2s/epoch - 2ms/step
# Epoch 83/150
# 1074/1074 - 2s - loss: 0.3482 - val_loss: 0.3508 - 2s/epoch - 2ms/step
# Epoch 84/150
# 1074/1074 - 2s - loss: 0.3482 - val_loss: 0.3509 - 2s/epoch - 2ms/step
# Epoch 85/150
# 1074/1074 - 2s - loss: 0.3482 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 86/150
# 1074/1074 - 2s - loss: 0.3482 - val_loss: 0.3513 - 2s/epoch - 2ms/step
# Epoch 87/150
# 1074/1074 - 2s - loss: 0.3481 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 88/150
# 1074/1074 - 2s - loss: 0.3481 - val_loss: 0.3508 - 2s/epoch - 2ms/step
# Epoch 89/150
# 1074/1074 - 2s - loss: 0.3481 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 90/150
# 1074/1074 - 2s - loss: 0.3481 - val_loss: 0.3508 - 2s/epoch - 2ms/step
# Epoch 91/150
# 1074/1074 - 2s - loss: 0.3481 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 92/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3508 - 2s/epoch - 2ms/step
# Epoch 93/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3504 - 2s/epoch - 2ms/step
# Epoch 94/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 95/150
# 1074/1074 - 2s - loss: 0.3481 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 96/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 97/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 98/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3504 - 2s/epoch - 2ms/step
# Epoch 99/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 100/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3509 - 2s/epoch - 2ms/step
# Epoch 101/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 102/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 103/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3508 - 2s/epoch - 2ms/step
# Epoch 104/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3504 - 2s/epoch - 2ms/step
# Epoch 105/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 106/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 107/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 108/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 109/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 110/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3504 - 2s/epoch - 2ms/step
# Epoch 111/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 112/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3506 - 2s/epoch - 2ms/step
# Epoch 113/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3506 - 2s/epoch - 2ms/step
# Epoch 114/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 115/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3504 - 2s/epoch - 2ms/step
# Epoch 116/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3512 - 2s/epoch - 2ms/step
# Epoch 117/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 118/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3514 - 2s/epoch - 2ms/step
# Epoch 119/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3502 - 2s/epoch - 2ms/step
# Epoch 120/150
# 1074/1074 - 2s - loss: 0.3480 - val_loss: 0.3506 - 2s/epoch - 2ms/step
# Epoch 121/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3508 - 2s/epoch - 2ms/step
# Epoch 122/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 123/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 124/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3508 - 2s/epoch - 2ms/step
# Epoch 125/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 126/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3502 - 2s/epoch - 2ms/step
# Epoch 127/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3506 - 2s/epoch - 2ms/step
# Epoch 128/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 129/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 130/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3506 - 2s/epoch - 2ms/step
# Epoch 131/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 132/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3502 - 2s/epoch - 2ms/step
# Epoch 133/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 134/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 135/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3500 - 2s/epoch - 2ms/step
# Epoch 136/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3506 - 2s/epoch - 2ms/step
# Epoch 137/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3506 - 2s/epoch - 2ms/step
# Epoch 138/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3501 - 2s/epoch - 2ms/step
# Epoch 139/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 140/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 141/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3504 - 2s/epoch - 2ms/step
# Epoch 142/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 143/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3505 - 2s/epoch - 2ms/step
# Epoch 144/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3507 - 2s/epoch - 2ms/step
# Epoch 145/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3503 - 2s/epoch - 2ms/step
# Epoch 146/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3502 - 2s/epoch - 2ms/step
# Epoch 147/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3511 - 2s/epoch - 2ms/step
# Epoch 148/150
# 1074/1074 - 2s - loss: 0.3479 - val_loss: 0.3504 - 2s/epoch - 2ms/step
# Epoch 149/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3501 - 2s/epoch - 2ms/step
# Epoch 150/150
# 1074/1074 - 2s - loss: 0.3478 - val_loss: 0.3503 - 2s/epoch - 2ms/step

# %%
autoencoder.save_weights('ae_mlp.h5')

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MAE)')
plt.legend()
plt.title('Autoencoder Training Performance')
plt.show()

# %% [markdown]
# Training after 120 epochs dose not lead to any accuracy increase. Training has saturated.

# %%
# Evaluate on test data
reconstructions = autoencoder.predict(X_test)
reconstruction_loss = np.mean(np.square(reconstructions - X_test), axis=1)

print(f"Mean Reconstruction Loss on Test Data: {np.mean(reconstruction_loss):.4f}")
# Out:
# 461/461 [==============================] - 1s 1ms/step
# Mean Reconstruction Loss on Test Data: 0.7936

# %% [markdown]
# **Task 3: anomaly detection**
#
# From the histogram of the reconstruction error decide what the cutoff should be applied to distinguish anomalies from valid samples, given that the anomaly rate is ~7%.

# %%
import numpy as np

# Get reconstructed values for the test data
reconstructions = autoencoder.predict(X_test)

# Calculate reconstruction error for each sample
reconstruction_errors = np.mean(np.square(reconstructions - X_test), axis=1)
# Out:
# 461/461 [==============================] - 1s 1ms/step

# %%
# Compute the cut-off threshold at the 93rd percentile (top 7%)
cutoff = np.percentile(reconstruction_errors, 93)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(reconstruction_errors, bins=50, alpha=0.7, color='blue', edgecolor='black')

# Add the cut-off line
plt.axvline(cutoff, color='red', linestyle='dashed', linewidth=2, label=f"Top 7% Cutoff ({cutoff:.3f})")

# Labels and title
plt.xlabel("Reconstruction Error")
plt.ylabel("Frequency")
plt.title("Histogram of Reconstruction Errors")
plt.legend()
plt.show()

# %% [markdown]
# The cutoff should be 1.563 for 7% anomalies. Of course we typically will not know the 7% point. Therefore we will need typically statistical methods like standard deviations or ROC which I will use below.

# %%
# Calculate the 95th percentile as the cutoff for anomalies
threshold = np.percentile(reconstruction_errors, 95)

# Print the threshold
print(f"Cutoff Threshold for Anomalies: {threshold:.4f}")
# Out:
# Cutoff Threshold for Anomalies: 3.2242

# %%
# Classify samples as anomalies
anomalies = reconstruction_errors > threshold

# Print the number of anomalies
print(f"Number of anomalies: {np.sum(anomalies)}")
# Out:
# Number of anomalies: 737

# %%
# Get the total number of arrays (rows) in the 2D array
num_rows = X_test.shape[0]

# Print the number of rows (arrays)
print(f"Total number of arrays (rows): {num_rows}")
# Out:
# Total number of arrays (rows): 14730

# %%
print(np.sum(anomalies)/num_rows)
# Out:
# 0.050033944331296674

# %%
# Extract the anomalous rows from the test data
anomalous_samples = X_test[anomalies]

# Optionally, display the anomalous samples
print("Anomalous Samples:")
print(anomalous_samples)
# Out:
# Anomalous Samples:
# [[ 2.34843921e+00  2.81376347e-02 -4.59504544e-01 ... -2.55541686e+00
#    3.66518633e+00  4.56948875e+00]
#  [ 4.60918884e+00  3.90402896e-03  2.48988206e+00 ... -2.77968308e+00
#   -6.45440008e-01  1.01020204e+00]
#  [ 2.50435298e+00  3.90402896e-03 -1.19190706e-01 ... -2.55541686e+00
#    3.66518633e+00  4.56948875e+00]
#  ...
#  [ 2.66026675e+00  5.23712405e-02 -1.19190706e-01 ... -2.55541686e+00
#    2.78346731e+00  3.89152938e+00]
#  [ 2.66026675e+00 -3.24463797e-02 -5.75275939e-03 ... -2.55541686e+00
#    3.81213950e+00  4.73897860e+00]
#  [ 2.58230986e+00  3.90402896e-03 -1.19190706e-01 ... -2.55541686e+00
#    3.91010828e+00  4.82372352e+00]]

# %%
# Transform the training data into the latent space
latent_space = encoded.predict(X_train)

# Plot the latent space
import matplotlib.pyplot as plt

plt.scatter(latent_space[:, 0], latent_space[:, 1], c='blue', alpha=0.5)
plt.xlabel('Latent Variable 1')
plt.ylabel('Latent Variable 2')
plt.title('Latent Space Visualization')
plt.grid(True)
plt.show()
# Out:
# 1074/1074 [==============================] - 1s 1ms/step

# %% [markdown]
# There is some structure with clusters. As expected for an autoencoder this structure is not very symmetric. The anomalies are presumably the onesfar from the dense cluster.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Transform the training data into the latent space
latent_space = encoded.predict(X_train)

# Ensure Y_train is a NumPy array and flattened
Y_train_array = np.array(Y_train).flatten()  # Convert to a 1D NumPy array if it's a DataFrame or Series

# Define colors: Normal samples (blue), Anomalies (red)
colors = np.array(['blue'] * len(Y_train_array))  # Default all to blue
colors[Y_train_array == 1] = 'red'  # Set anomalies to red

# Plot the latent space with different colors for anomalies
plt.figure(figsize=(8, 6))
plt.scatter(latent_space[:, 0], latent_space[:, 1], c=colors, alpha=0.5)
plt.xlabel('Latent Variable 1')
plt.ylabel('Latent Variable 2')
plt.title('Latent Space Visualization')
plt.grid(True)

# Add legend
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Normal', markersize=8, markerfacecolor='blue'),
                   Line2D([0], [0], marker='o', color='w', label='Anomaly', markersize=8, markerfacecolor='red')]
plt.legend(handles=legend_elements)

plt.show()
# Out:
# 1074/1074 [==============================] - 1s 1ms/step

# %% [markdown]
# As expected the actual anomalies are outside of the main cluster. Each time I run this I get a different cluster.

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Step 1: Get model predictions (Reconstruction Errors)
reconstructions = autoencoder.predict(X_test)  # X_test is the test data
reconstruction_errors = np.mean(np.square(X_test - reconstructions), axis=1)

# Step 2: Set an anomaly detection threshold (e.g., 95th percentile)
threshold = np.percentile(reconstruction_errors, 95)

# Step 3: Predict anomalies based on threshold
y_pred = (reconstruction_errors > threshold).astype(int)  # 1 = Anomaly, 0 = Normal

# Step 4: Get actual labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual anomaly labels

# Step 5: Compute Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Step 6: Plot Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Step 7: Print Classification Report
print(classification_report(y_true, y_pred))
# Out:
# 461/461 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     13677
#            1       0.98      0.68      0.80      1053
#
#     accuracy                           0.98     14730
#    macro avg       0.98      0.84      0.90     14730
# weighted avg       0.98      0.98      0.97     14730

# %% [markdown]
# The recall for anomalies is very poor.

# %%
print(cm)
# Out:
# [[13659    18]
#  [  334   719]]

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc

# Step 1: Get model predictions (Reconstruction Errors)
reconstructions = autoencoder.predict(X_test)  
reconstruction_errors = np.mean(np.square(X_test - reconstructions), axis=1)

# Step 2: Get actual labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual anomaly labels

# Step 3: Compute ROC Curve
fpr, tpr, thresholds = roc_curve(y_true, reconstruction_errors)

# Step 4: Compute AUC (Area Under Curve)
roc_auc = auc(fpr, tpr)

# Step 5: Plot ROC Curve
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal reference line

# Display AUC score on plot
plt.text(0.6, 0.2, f'AUC = {roc_auc:.2f}', fontsize=12, bbox=dict(facecolor='white', alpha=0.7))

# Formatting
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid()

# Show plot
plt.show()
# Out:
# 461/461 [==============================] - 1s 1ms/step

# %% [markdown]
# This is a very high AUC

# %% [markdown]
# Lets use the ROC cureve to find the best Threshold

# %%
# Compute Youden's J statistic
youden_j = tpr - fpr
best_index = np.argmax(youden_j)  # Index of max Youden's J
best_threshold = thresholds[best_index]

# %% [markdown]
# Now lets print the anomalies

# %%
# Classify samples as anomalies
anomalies = reconstruction_errors > best_threshold

# Print the number of anomalies
print(f"Number of anomalies: {np.sum(anomalies)}")

# Get the total number of arrays (rows) in the 2D array
num_rows = X_test.shape[0]

# Print the number of rows (arrays)
print(f"Total number of arrays (rows): {num_rows}")
# Out:
# Number of anomalies: 1016
# Total number of arrays (rows): 14730

# %% [markdown]
# This is just over 7% of an anomally rate

# %%
y_pred = (reconstruction_errors > best_threshold).astype(int)  # 1 = Anomaly, 0 = Normal
# Step 4: Get actual labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual anomaly labels

# Step 5: Compute Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Step 6: Plot Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Step 7: Print Classification Report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13677
#            1       0.98      0.94      0.96      1053
#
#     accuracy                           0.99     14730
#    macro avg       0.99      0.97      0.98     14730
# weighted avg       0.99      0.99      0.99     14730

# %% [markdown]
# This is better with a stronger combination of recall and precision. Anomalies have 1. F1 scoe of 0.921 is high.

# %% [markdown]
# We can try with 7% threshold also

# %%
seven_threshold=1.563
y_pred = (reconstruction_errors > seven_threshold).astype(int)  # 1 = Anomaly, 0 = Normal
# Step 4: Get actual labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual anomaly labels

# Step 5: Compute Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Step 6: Plot Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Step 7: Print Classification Report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13677
#            1       0.94      0.94      0.94      1053
#
#     accuracy                           0.99     14730
#    macro avg       0.97      0.97      0.97     14730
# weighted avg       0.99      0.99      0.99     14730

# %% [markdown]
# This has the best accuracy but of course requires prior knowledge

# %% [markdown]
# ### Post (complete by Sunday 02/02/25)
#
# Once you have an implemntation however rough, use the forums/topics to advertise the fact. The purpose is to get feedback from others in the group, so if you have only a basic outline then you may get ideas about how to proceed and also examples from others in your group.
#
# No posts should refer to Task 4.

# %% [markdown]
# ### Respond (complete by Wednesday 05/02/24)
#
# If you feel you can provide useful advise then respond to another member of the group through the appropriate forum. Responses should be respectful and offer some sort of advise. Try and avoid clogging the forums with support or thank you messages.
#
# In reviewing others code you will discover different ways to tackle the same problem. It is acceptable to copy parts of others code. However whole scale copying from another notebook is not acceptable.
#
# If you stick to the deadline then it will allow yourself and others to have enough time to implement suggestions. From the Schedule you can see that this is not a hard deadline.
#
# The posts on the forum/topic associated with this e-tivity are graded. Below is a link to the rubrics.
#
# https://learn.ul.ie/d2l/lp/rubrics/preview.d2l?ou=49284&rubricId=2620&originTool=quicklinks

# %% [markdown]
# ### Task 4: VAE (completed by Sunday 09/02/24)
#
# This task is a individual task and should **not** to be uploaded to the Group Locker. No direct support should be given via the forums. Marks will be deducted if the instructions are not followed (see rubrics). This part should be uploaded directly to Brightpsace.
#
# Change the network to be a VAE. Again determine the optimal cutoff and plot the latent variables. Check how good the cutoffs were by constructing a confusion matrix or generating a classification report. Obviously for this task you need to use the Anom column.
#
# **Hint** you can use the model topology from the AE (with the obvious modifications). I found that I had a good model (almost as good and the supervised learning model) when the KL divergence was small. You can print out both the KL divergence and reconstruction loss for each epoch. It can be tricky to train these type of models, so do not be surprised if you do not get a stellar result. What is more important is that you have the correct code to implement the VAE.

# %% [markdown]
# ### Final Submission (complete by Sunday 09/02/24)
#
# Submit Tasks 1-4 in a single notebook this before the deadline on Sunday.

# %%
## Add additional code cells to implememt the tasks stated above

# %%
import tensorflow.keras.backend as K

latent_dim = 2  # Latent space with 2 variables

# ---- Encoder ----
inputs = layers.Input(shape=(input_dim,))
x = layers.Dense(6, activation='relu', kernel_initializer='he_normal')(inputs)
x = layers.Dense(4, activation='relu', kernel_initializer='he_normal')(x)

# Latent space: Mean and Log Variance
z_mean = layers.Dense(latent_dim, name='z_mean')(x)
z_log_var = layers.Dense(latent_dim, name='z_log_var',activation='linear')(x)

# Reparameterization Trick
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=K.shape(z_mean))  # Noise
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

z = layers.Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

# Encoder model
encoder = Model(inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()


# ---- Decoder ----
latent_inputs = layers.Input(shape=(latent_dim,))
x = layers.Dense(4, activation='relu', kernel_initializer='he_normal')(latent_inputs)
x = layers.Dense(6, activation='relu', kernel_initializer='he_normal')(x)
outputs1 = layers.Dense(input_dim, activation='sigmoid')(x)  # Sigmoid for pixel intensity

# Decoder model
decoder = Model(latent_inputs, outputs, name="decoder")
decoder.summary()


# ---- VAE Model ----
z_mean, z_log_var, z = encoder(inputs)
reconstructions1 = decoder(z)

vae = Model(inputs, reconstructions1, name="vae")

# Summary
vae.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 9)]                  0         []
#
#  dense_15 (Dense)            (None, 6)                    60        ['input_7[0][0]']
#
#  dense_16 (Dense)            (None, 4)                    28        ['dense_15[0][0]']
#
#  z_mean (Dense)              (None, 2)                    10        ['dense_16[0][0]']
#
#  z_log_var (Dense)           (None, 2)                    10        ['dense_16[0][0]']
#
#  z (Lambda)                  (None, 2)                    0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 108 (432.00 Byte)
# Trainable params: 108 (432.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 2)]               0
#
#  dense_17 (Dense)            (None, 4)                 12
#
#  dense_18 (Dense)            (None, 6)                 30
#
#  dense_19 (Dense)            (None, 9)                 63
#
# =================================================================
# Total params: 105 (420.00 Byte)
# Trainable params: 105 (420.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "vae"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 9)]               0
#
#  encoder (Functional)        [(None, 2),               108
#                               (None, 2),
#                               (None, 2)]
#
#  decoder (Functional)        (None, 9)                 105
#
# =================================================================
# Total params: 213 (852.00 Byte)
# Trainable params: 213 (852.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Calculate reconstruction loss (Mean Squared Error)
reconstruction_loss = K.mean(K.square(reconstructions1 - inputs), axis=1)

# KL divergence loss (regularization)
z = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = -0.5 * K.sum(z, axis=-1)  # Sum over the latent dimension
kl_loss = K.mean(kl_loss)  # Take the mean across the batch

# Total VAE loss: reconstruction loss + KL divergence loss
vae_loss_tot = reconstruction_loss + kl_loss


# Add the custom loss to the VAE model
vae.add_loss(vae_loss_tot)

# Compile the model
vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, clipvalue=1.0))
# Out:
# WARNING:tensorflow:From C:\Users\noona\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Create a custom callback to print KL and reconstruction loss during training
class PrintLosses(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        # logs contains the losses from training
        reconstruction_loss_value = logs.get('loss')  # This is the VAE loss
        kl_loss_value = logs.get('val_loss')  # This is the validation loss
        
        # Print the losses
        print(f"Epoch {epoch+1}: Reconstruction Loss = {reconstruction_loss_value}, KL Divergence = {kl_loss_value}")

# %%
batch_size = 64
# Train the autoencoder
history1 = vae.fit(
    X_train,
    X_train,  # Input and output are the same for an autoencoder
    validation_data=(X_test, X_test),
    epochs=100,
    batch_size=batch_size,
    shuffle=True,
    verbose=2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True),
        PrintLosses()
    ]
)
# Out:
# Epoch 1/100
# Epoch 1: Reconstruction Loss = 2475168000.0, KL Divergence = 7392332.0
# 537/537 - 2s - loss: 2475168000.0000 - val_loss: 7392332.0000 - 2s/epoch - 4ms/step
# Epoch 2/100
# Epoch 2: Reconstruction Loss = 19199110.0, KL Divergence = 109657.390625
# 537/537 - 1s - loss: 19199110.0000 - val_loss: 109657.3906 - 1s/epoch - 2ms/step
# Epoch 3/100
# Epoch 3: Reconstruction Loss = 1945243.25, KL Divergence = 30808.041015625
# 537/537 - 1s - loss: 1945243.2500 - val_loss: 30808.0410 - 1s/epoch - 2ms/step
# Epoch 4/100
# Epoch 4: Reconstruction Loss = 687670.4375, KL Divergence = 17012.224609375
# 537/537 - 1s - loss: 687670.4375 - val_loss: 17012.2246 - 1s/epoch - 2ms/step
# Epoch 5/100
# Epoch 5: Reconstruction Loss = 109291.578125, KL Divergence = 6997.35546875
# 537/537 - 1s - loss: 109291.5781 - val_loss: 6997.3555 - 1s/epoch - 2ms/step
# Epoch 6/100
# Epoch 6: Reconstruction Loss = 34512.25390625, KL Divergence = 1995.7366943359375
# 537/537 - 1s - loss: 34512.2539 - val_loss: 1995.7367 - 1s/epoch - 2ms/step
# Epoch 7/100
# Epoch 7: Reconstruction Loss = 6675.953125, KL Divergence = 459.0583801269531
# 537/537 - 1s - loss: 6675.9531 - val_loss: 459.0584 - 1s/epoch - 2ms/step
# Epoch 8/100
# Epoch 8: Reconstruction Loss = 1389.1785888671875, KL Divergence = 109.01828002929688
# 537/537 - 1s - loss: 1389.1786 - val_loss: 109.0183 - 1s/epoch - 2ms/step
# Epoch 9/100
# Epoch 9: Reconstruction Loss = 292.9327087402344, KL Divergence = 25.592449188232422
# 537/537 - 1s - loss: 292.9327 - val_loss: 25.5924 - 1s/epoch - 2ms/step
# Epoch 10/100
# Epoch 10: Reconstruction Loss = 73.72760009765625, KL Divergence = 7.269234657287598
# 537/537 - 1s - loss: 73.7276 - val_loss: 7.2692 - 1s/epoch - 2ms/step
# Epoch 11/100
# Epoch 11: Reconstruction Loss = 12.633116722106934, KL Divergence = 2.84415602684021
# 537/537 - 1s - loss: 12.6331 - val_loss: 2.8442 - 1s/epoch - 2ms/step
# Epoch 12/100
# Epoch 12: Reconstruction Loss = 3.1220171451568604, KL Divergence = 1.5967532396316528
# 537/537 - 1s - loss: 3.1220 - val_loss: 1.5968 - 1s/epoch - 2ms/step
# Epoch 13/100
# Epoch 13: Reconstruction Loss = 1.523274540901184, KL Divergence = 1.22223961353302
# 537/537 - 1s - loss: 1.5233 - val_loss: 1.2222 - 1s/epoch - 2ms/step
# Epoch 14/100
# Epoch 14: Reconstruction Loss = 1.1895838975906372, KL Divergence = 1.1034622192382812
# 537/537 - 1s - loss: 1.1896 - val_loss: 1.1035 - 1s/epoch - 2ms/step
# Epoch 15/100
# Epoch 15: Reconstruction Loss = 1.0851795673370361, KL Divergence = 1.0541942119598389
# 537/537 - 1s - loss: 1.0852 - val_loss: 1.0542 - 1s/epoch - 2ms/step
# Epoch 16/100
# Epoch 16: Reconstruction Loss = 1.034895658493042, KL Divergence = 1.032123327255249
# 537/537 - 1s - loss: 1.0349 - val_loss: 1.0321 - 1s/epoch - 2ms/step
# Epoch 17/100
# Epoch 17: Reconstruction Loss = 1.0213291645050049, KL Divergence = 1.0202147960662842
# 537/537 - 1s - loss: 1.0213 - val_loss: 1.0202 - 1s/epoch - 2ms/step
# Epoch 18/100
# Epoch 18: Reconstruction Loss = 1.0136791467666626, KL Divergence = 1.0140372514724731
# 537/537 - 1s - loss: 1.0137 - val_loss: 1.0140 - 1s/epoch - 2ms/step
# Epoch 19/100
# Epoch 19: Reconstruction Loss = 1.0097298622131348, KL Divergence = 1.0099996328353882
# 537/537 - 1s - loss: 1.0097 - val_loss: 1.0100 - 1s/epoch - 2ms/step
# Epoch 20/100
# Epoch 20: Reconstruction Loss = 1.0073134899139404, KL Divergence = 1.0076195001602173
# 537/537 - 1s - loss: 1.0073 - val_loss: 1.0076 - 1s/epoch - 2ms/step
# Epoch 21/100
# Epoch 21: Reconstruction Loss = 1.00620436668396, KL Divergence = 1.0058722496032715
# 537/537 - 1s - loss: 1.0062 - val_loss: 1.0059 - 1s/epoch - 2ms/step
# Epoch 22/100
# Epoch 22: Reconstruction Loss = 1.0050528049468994, KL Divergence = 1.0048538446426392
# 537/537 - 1s - loss: 1.0051 - val_loss: 1.0049 - 1s/epoch - 2ms/step
# Epoch 23/100
# Epoch 23: Reconstruction Loss = 1.0042542219161987, KL Divergence = 1.0041042566299438
# 537/537 - 1s - loss: 1.0043 - val_loss: 1.0041 - 1s/epoch - 2ms/step
# Epoch 24/100
# Epoch 24: Reconstruction Loss = 1.003849744796753, KL Divergence = 1.0034459829330444
# 537/537 - 1s - loss: 1.0038 - val_loss: 1.0034 - 1s/epoch - 2ms/step
# Epoch 25/100
# Epoch 25: Reconstruction Loss = 1.0034632682800293, KL Divergence = 1.0027378797531128
# 537/537 - 1s - loss: 1.0035 - val_loss: 1.0027 - 979ms/epoch - 2ms/step
# Epoch 26/100
# Epoch 26: Reconstruction Loss = 1.0028839111328125, KL Divergence = 1.0023072957992554
# 537/537 - 1s - loss: 1.0029 - val_loss: 1.0023 - 1s/epoch - 2ms/step
# Epoch 27/100
# Epoch 27: Reconstruction Loss = 1.002798080444336, KL Divergence = 1.0018160343170166
# 537/537 - 1s - loss: 1.0028 - val_loss: 1.0018 - 1s/epoch - 2ms/step
# Epoch 28/100
# Epoch 28: Reconstruction Loss = 1.0023952722549438, KL Divergence = 1.0016447305679321
# 537/537 - 1s - loss: 1.0024 - val_loss: 1.0016 - 1s/epoch - 2ms/step
# Epoch 29/100
# Epoch 29: Reconstruction Loss = 1.0021225214004517, KL Divergence = 1.0015194416046143
# 537/537 - 1s - loss: 1.0021 - val_loss: 1.0015 - 1s/epoch - 2ms/step
# Epoch 30/100
# Epoch 30: Reconstruction Loss = 1.0019299983978271, KL Divergence = 1.0011100769042969
# 537/537 - 1s - loss: 1.0019 - val_loss: 1.0011 - 1s/epoch - 2ms/step
# Epoch 31/100
# Epoch 31: Reconstruction Loss = 1.0017037391662598, KL Divergence = 1.0010102987289429
# 537/537 - 1s - loss: 1.0017 - val_loss: 1.0010 - 1s/epoch - 2ms/step
# Epoch 32/100
# Epoch 32: Reconstruction Loss = 1.0015429258346558, KL Divergence = 1.0008058547973633
# 537/537 - 1s - loss: 1.0015 - val_loss: 1.0008 - 1s/epoch - 2ms/step
# Epoch 33/100
# Epoch 33: Reconstruction Loss = 1.0013575553894043, KL Divergence = 1.0006883144378662
# 537/537 - 1s - loss: 1.0014 - val_loss: 1.0007 - 1s/epoch - 2ms/step
# Epoch 34/100
# Epoch 34: Reconstruction Loss = 1.0014193058013916, KL Divergence = 1.0006639957427979
# 537/537 - 1s - loss: 1.0014 - val_loss: 1.0007 - 1s/epoch - 2ms/step
# Epoch 35/100
# Epoch 35: Reconstruction Loss = 1.0012972354888916, KL Divergence = 1.0006293058395386
# 537/537 - 1s - loss: 1.0013 - val_loss: 1.0006 - 1s/epoch - 2ms/step
# Epoch 36/100
# Epoch 36: Reconstruction Loss = 1.001191258430481, KL Divergence = 1.000485897064209
# 537/537 - 1s - loss: 1.0012 - val_loss: 1.0005 - 1s/epoch - 2ms/step
# Epoch 37/100
# Epoch 37: Reconstruction Loss = 1.0009969472885132, KL Divergence = 1.000402569770813
# 537/537 - 1s - loss: 1.0010 - val_loss: 1.0004 - 1s/epoch - 2ms/step
# Epoch 38/100
# Epoch 38: Reconstruction Loss = 1.0009816884994507, KL Divergence = 1.000422477722168
# 537/537 - 1s - loss: 1.0010 - val_loss: 1.0004 - 1s/epoch - 2ms/step
# Epoch 39/100
# Epoch 39: Reconstruction Loss = 1.000849723815918, KL Divergence = 1.0003923177719116
# 537/537 - 1s - loss: 1.0008 - val_loss: 1.0004 - 1s/epoch - 2ms/step
# Epoch 40/100
# Epoch 40: Reconstruction Loss = 1.0008563995361328, KL Divergence = 1.000353217124939
# 537/537 - 1s - loss: 1.0009 - val_loss: 1.0004 - 1s/epoch - 2ms/step
# Epoch 41/100
# Epoch 41: Reconstruction Loss = 1.000715732574463, KL Divergence = 1.0003881454467773
# 537/537 - 1s - loss: 1.0007 - val_loss: 1.0004 - 1s/epoch - 2ms/step
# Epoch 42/100
# Epoch 42: Reconstruction Loss = 1.000813603401184, KL Divergence = 1.0003609657287598
# 537/537 - 1s - loss: 1.0008 - val_loss: 1.0004 - 1s/epoch - 2ms/step
# Epoch 43/100
# Epoch 43: Reconstruction Loss = 1.0007030963897705, KL Divergence = 1.0002998113632202
# 537/537 - 1s - loss: 1.0007 - val_loss: 1.0003 - 1s/epoch - 2ms/step
# Epoch 44/100
# Epoch 44: Reconstruction Loss = 1.0006887912750244, KL Divergence = 1.0002779960632324
# 537/537 - 1s - loss: 1.0007 - val_loss: 1.0003 - 1s/epoch - 2ms/step
# Epoch 45/100
# Epoch 45: Reconstruction Loss = 1.0006409883499146, KL Divergence = 1.000272512435913
# 537/537 - 1s - loss: 1.0006 - val_loss: 1.0003 - 1s/epoch - 2ms/step
# Epoch 46/100
# Epoch 46: Reconstruction Loss = 1.000707983970642, KL Divergence = 1.000198483467102
# 537/537 - 1s - loss: 1.0007 - val_loss: 1.0002 - 983ms/epoch - 2ms/step
# Epoch 47/100
# Epoch 47: Reconstruction Loss = 1.0007059574127197, KL Divergence = 1.000240445137024
# 537/537 - 1s - loss: 1.0007 - val_loss: 1.0002 - 1s/epoch - 2ms/step
# Epoch 48/100
# Epoch 48: Reconstruction Loss = 1.000534176826477, KL Divergence = 1.000194787979126
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0002 - 1s/epoch - 2ms/step
# Epoch 49/100
# Epoch 49: Reconstruction Loss = 1.000531554222107, KL Divergence = 1.0002070665359497
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0002 - 1s/epoch - 2ms/step
# Epoch 50/100
# Epoch 50: Reconstruction Loss = 1.0005335807800293, KL Divergence = 1.0001802444458008
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0002 - 1s/epoch - 2ms/step
# Epoch 51/100
# Epoch 51: Reconstruction Loss = 1.0007296800613403, KL Divergence = 1.0001890659332275
# 537/537 - 1s - loss: 1.0007 - val_loss: 1.0002 - 1s/epoch - 2ms/step
# Epoch 52/100
# Epoch 52: Reconstruction Loss = 1.000497579574585, KL Divergence = 1.00014328956604
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 53/100
# Epoch 53: Reconstruction Loss = 1.0005979537963867, KL Divergence = 1.0001168251037598
# 537/537 - 1s - loss: 1.0006 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 54/100
# Epoch 54: Reconstruction Loss = 1.0006083250045776, KL Divergence = 1.0001024007797241
# 537/537 - 1s - loss: 1.0006 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 55/100
# Epoch 55: Reconstruction Loss = 1.0005697011947632, KL Divergence = 1.0001230239868164
# 537/537 - 1s - loss: 1.0006 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 56/100
# Epoch 56: Reconstruction Loss = 1.0004396438598633, KL Divergence = 1.0001498460769653
# 537/537 - 1s - loss: 1.0004 - val_loss: 1.0001 - 974ms/epoch - 2ms/step
# Epoch 57/100
# Epoch 57: Reconstruction Loss = 1.0004688501358032, KL Divergence = 1.0001486539840698
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 58/100
# Epoch 58: Reconstruction Loss = 1.0005050897598267, KL Divergence = 1.0001128911972046
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0001 - 989ms/epoch - 2ms/step
# Epoch 59/100
# Epoch 59: Reconstruction Loss = 1.0003743171691895, KL Divergence = 1.0000898838043213
# 537/537 - 1s - loss: 1.0004 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 60/100
# Epoch 60: Reconstruction Loss = 1.000410556793213, KL Divergence = 1.0000810623168945
# 537/537 - 1s - loss: 1.0004 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 61/100
# Epoch 61: Reconstruction Loss = 1.000455617904663, KL Divergence = 1.0000782012939453
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 62/100
# Epoch 62: Reconstruction Loss = 1.0004645586013794, KL Divergence = 1.0000711679458618
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 63/100
# Epoch 63: Reconstruction Loss = 1.0004090070724487, KL Divergence = 1.0000687837600708
# 537/537 - 1s - loss: 1.0004 - val_loss: 1.0001 - 981ms/epoch - 2ms/step
# Epoch 64/100
# Epoch 64: Reconstruction Loss = 1.000451922416687, KL Divergence = 1.0000747442245483
# 537/537 - 1s - loss: 1.0005 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 65/100
# Epoch 65: Reconstruction Loss = 1.0003259181976318, KL Divergence = 1.0000711679458618
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 66/100
# Epoch 66: Reconstruction Loss = 1.0003955364227295, KL Divergence = 1.000049114227295
# 537/537 - 1s - loss: 1.0004 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 67/100
# Epoch 67: Reconstruction Loss = 1.0004146099090576, KL Divergence = 1.0000795125961304
# 537/537 - 1s - loss: 1.0004 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 68/100
# Epoch 68: Reconstruction Loss = 1.0003772974014282, KL Divergence = 1.0000519752502441
# 537/537 - 1s - loss: 1.0004 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 69/100
# Epoch 69: Reconstruction Loss = 1.000356912612915, KL Divergence = 1.0000635385513306
# 537/537 - 1s - loss: 1.0004 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 70/100
# Epoch 70: Reconstruction Loss = 1.0003248453140259, KL Divergence = 1.000066876411438
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 71/100
# Epoch 71: Reconstruction Loss = 1.0003101825714111, KL Divergence = 1.0000593662261963
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 72/100
# Epoch 72: Reconstruction Loss = 1.0003323554992676, KL Divergence = 1.0000457763671875
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 73/100
# Epoch 73: Reconstruction Loss = 1.0003385543823242, KL Divergence = 1.000045657157898
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 74/100
# Epoch 74: Reconstruction Loss = 1.0003474950790405, KL Divergence = 1.000056505203247
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 75/100
# Epoch 75: Reconstruction Loss = 1.0002522468566895, KL Divergence = 1.0000582933425903
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 76/100
# Epoch 76: Reconstruction Loss = 1.000252366065979, KL Divergence = 1.0000594854354858
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0001 - 955ms/epoch - 2ms/step
# Epoch 77/100
# Epoch 77: Reconstruction Loss = 1.000299334526062, KL Divergence = 1.0000543594360352
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 78/100
# Epoch 78: Reconstruction Loss = 1.0002636909484863, KL Divergence = 1.0000529289245605
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 79/100
# Epoch 79: Reconstruction Loss = 1.0002909898757935, KL Divergence = 1.0000349283218384
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 80/100
# Epoch 80: Reconstruction Loss = 1.0002890825271606, KL Divergence = 1.000038504600525
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0000 - 984ms/epoch - 2ms/step
# Epoch 81/100
# Epoch 81: Reconstruction Loss = 1.0002607107162476, KL Divergence = 1.000038504600525
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 82/100
# Epoch 82: Reconstruction Loss = 1.0002199411392212, KL Divergence = 1.0000500679016113
# 537/537 - 1s - loss: 1.0002 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 83/100
# Epoch 83: Reconstruction Loss = 1.0002028942108154, KL Divergence = 1.000046730041504
# 537/537 - 1s - loss: 1.0002 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 84/100
# Epoch 84: Reconstruction Loss = 1.0001615285873413, KL Divergence = 1.0000334978103638
# 537/537 - 1s - loss: 1.0002 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 85/100
# Epoch 85: Reconstruction Loss = 1.0002293586730957, KL Divergence = 1.0000334978103638
# 537/537 - 1s - loss: 1.0002 - val_loss: 1.0000 - 962ms/epoch - 2ms/step
# Epoch 86/100
# Epoch 86: Reconstruction Loss = 1.0002572536468506, KL Divergence = 1.00004243850708
# 537/537 - 1s - loss: 1.0003 - val_loss: 1.0000 - 992ms/epoch - 2ms/step
# Epoch 87/100
# Epoch 87: Reconstruction Loss = 1.0001602172851562, KL Divergence = 1.0000498294830322
# 537/537 - 1s - loss: 1.0002 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 88/100
# Epoch 88: Reconstruction Loss = 1.0001270771026611, KL Divergence = 1.0000481605529785
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 89/100
# Epoch 89: Reconstruction Loss = 1.0001318454742432, KL Divergence = 1.0000706911087036
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 90/100
# Epoch 90: Reconstruction Loss = 1.0001375675201416, KL Divergence = 1.0000474452972412
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 91/100
# Epoch 91: Reconstruction Loss = 1.000109076499939, KL Divergence = 1.0000473260879517
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 92/100
# Epoch 92: Reconstruction Loss = 1.0001194477081299, KL Divergence = 1.0000509023666382
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 93/100
# Epoch 93: Reconstruction Loss = 1.0001168251037598, KL Divergence = 1.0000464916229248
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 94/100
# Epoch 94: Reconstruction Loss = 1.0000836849212646, KL Divergence = 1.0000704526901245
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 95/100
# Epoch 95: Reconstruction Loss = 1.0000951290130615, KL Divergence = 1.0000622272491455
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0001 - 1s/epoch - 2ms/step
# Epoch 96/100
# Epoch 96: Reconstruction Loss = 1.000084638595581, KL Divergence = 1.0000460147857666
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 97/100
# Epoch 97: Reconstruction Loss = 1.000083565711975, KL Divergence = 1.0000414848327637
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 98/100
# Epoch 98: Reconstruction Loss = 1.0000656843185425, KL Divergence = 1.0000463724136353
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 99/100
# Epoch 99: Reconstruction Loss = 1.0000536441802979, KL Divergence = 1.0000396966934204
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step
# Epoch 100/100
# Epoch 100: Reconstruction Loss = 1.000059962272644, KL Divergence = 1.000042200088501
# 537/537 - 1s - loss: 1.0001 - val_loss: 1.0000 - 1s/epoch - 2ms/step

# %%
vae.save_weights('vae_mlp.h5')

# %%
# Plot training and validation loss
plt.plot(history1.history['loss'], label='Training Loss')
plt.plot(history1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('VAE Loss')
plt.legend()
plt.title('Variational Autoencoder Training Performance')
plt.show()

# %% [markdown]
# AFter 10 epochs the model accuracy does not particularly improve. There is a lareg step around 15 epochs where the model has likely fallen into a depp well of the loss function manifold.

# %%
import numpy as np

# Get model predictions (reconstructed data)
reconstructions1 = vae.predict(X_test)

# Compute reconstruction loss (MSE for each sample)
reconstruction_loss = np.mean(np.square(X_test - reconstructions1), axis=1)

# Print sample reconstruction losses
print("Reconstruction Loss (first 10 samples):", reconstruction_loss[:10])
# Out:
# 461/461 [==============================] - 1s 1ms/step
# Reconstruction Loss (first 10 samples): [0.2169131  0.32147204 0.10704441 0.05123655 0.79601914 0.06240091
#  0.11920065 0.18083835 0.25014373 0.06962777]

# %%
# Compute the cut-off threshold at the 93rd percentile (top 7%)
cutoff = np.percentile(reconstruction_loss, 93)

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.hist(reconstruction_loss, bins=50, alpha=0.7, color='blue', edgecolor='black')

# Add the cut-off line
plt.axvline(cutoff, color='red', linestyle='dashed', linewidth=2, label=f"Top 7% Cutoff ({cutoff:.3f})")

# Labels and title
plt.xlabel("Reconstruction Error")
plt.ylabel("Frequency")
plt.title("Histogram of Reconstruction Errors")
plt.legend()

# %%
# Select the 95th percentile as the anomaly threshold
threshold = np.percentile(reconstruction_loss, 95)

print(f"Selected Threshold: {threshold}")
# Out:
# Selected Threshold: 3.8782141817687497

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.histplot(reconstruction_loss, bins=50, kde=True, color='blue')
plt.axvline(threshold, color='red', linestyle='dashed', linewidth=2, label=f'Threshold: {threshold:.4f}')
plt.xlabel("Reconstruction Loss")
plt.ylabel("Frequency")
plt.title("Distribution of Reconstruction Loss")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\noona\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Predict anomalies: If reconstruction loss > threshold, classify as anomaly (1), else normal (0)
y_pred = (reconstruction_loss > threshold).astype(int)

# Print number of anomalies detected
print(f"Number of anomalies detected: {np.sum(y_pred)}")
# Out:
# Number of anomalies detected: 737

# %%
from sklearn.metrics import roc_curve, auc

# Get actual anomaly labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual labels

# Compute ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_true, reconstruction_loss)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='dashed')  # Random chance line
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("ROC Curve for VAE Anomaly Detection")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Transform the training data into the latent space
z_mean, z_log_var, z = encoder.predict(X_train)  # Ensure encoder has 3 outputs

latent_space = z_mean  # Use z_mean for visualization

# Ensure Y_train is a NumPy array and flattened
Y_train_array = np.array(Y_train).flatten()  # Convert to a 1D NumPy array if it's a DataFrame or Series

# Define colors: Normal samples (blue), Anomalies (red)
colors = np.array(['blue'] * len(Y_train_array))  # Default all to blue
colors[Y_train_array == 1] = 'red'  # Set anomalies to red

# Plot the latent space with different colors for anomalies
plt.figure(figsize=(8, 6))
plt.scatter(latent_space[:, 0], latent_space[:, 1], c=colors, alpha=0.5)
plt.xlabel('Latent Variable 1')
plt.ylabel('Latent Variable 2')
plt.title('Latent Space Visualization')
plt.grid(True)

# Add legend
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Normal', markersize=8, markerfacecolor='blue'),
                   Line2D([0], [0], marker='o', color='w', label='Anomaly', markersize=8, markerfacecolor='red')]
plt.legend(handles=legend_elements)

plt.show()
# Out:
# 1074/1074 [==============================] - 2s 1ms/step

# %% [markdown]
# This cluster is more centred around the (0,0) as expected as we are restricting our latent space to a normal distribution.

# %% [markdown]
# Different plots for each run as we are sampling from ditribution.

# %%
# Compute Youden's J statistic
youden_j = tpr - fpr
best_index = np.argmax(youden_j)  # Index of max Youden's J
best_threshold = thresholds[best_index]

# %%
# Classify samples as anomalies
anomalies = reconstruction_errors > best_threshold

# Print the number of anomalies
print(f"Number of anomalies: {np.sum(anomalies)}")

# Get the total number of arrays (rows) in the 2D array
num_rows = X_test.shape[0]

# Print the number of rows (arrays)
print(f"Total number of arrays (rows): {num_rows}")
# Out:
# Number of anomalies: 983
# Total number of arrays (rows): 14730

# %% [markdown]
# This is a 6% anomally rate which is slightly low

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Step 1: Get model predictions (Reconstruction Errors)
reconstructions = vae.predict(X_test)  # X_test is the test data
reconstruction_errors = np.mean(np.square(X_test - reconstructions), axis=1)

# Step 2: Set an anomaly detection threshold (e.g., 95th percentile)
threshold = np.percentile(reconstruction_errors, 95)

# Step 3: Predict anomalies based on threshold
y_pred = (reconstruction_errors > threshold).astype(int)  # 1 = Anomaly, 0 = Normal
y_pred = (reconstruction_errors > best_threshold).astype(int)  # 1 = Anomaly, 0 = Normal

# Step 4: Get actual labels (assuming 1 = Anomaly, 0 = Normal)
y_true = Y_test  # Replace with actual anomaly labels

# Step 5: Compute Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Step 6: Plot Confusion Matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Anomaly'], yticklabels=['Normal', 'Anomaly'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Step 7: Print Classification Report
print(classification_report(y_true, y_pred))
# Out:
# 461/461 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     13677
#            1       0.97      0.94      0.95      1053
#
#     accuracy                           0.99     14730
#    macro avg       0.98      0.97      0.98     14730
# weighted avg       0.99      0.99      0.99     14730

# %% [markdown]
# This performs very well on the test data

# %% [markdown]
# ## Reflection
#
# There are no specific marks allocated for a reflection. However due consideration will be given if pertinent comments or valuable insights are made.

# %% [markdown]
# This task required building an autoencoder and variational autoencoder for data in order to predict anomalies.
#
# Initial data nanalysis showed high corrrelations between particular variables and anomalies which meant dimensional reduction  ould likely be successful.
#
# The first issue I had was data snooping. I applied the scaler function before separating train and tets data. The scaler function relaly helps the autoencoder to train.I ensured equal number of anomalies in both train and test sets. This ws recommended by one of my peers.
#
# ### Autoencoder
# The layers between the latent space had reducing number of dimensions. I inially had too high of numbers here which one of my peers spotted.
#
# Th latent space dhiwed a cluster with no strcit shape.
#
# Anomalies were considered as those with reconstruction errors greater than the 95th percentile. This threshold was set along with 93rd percentile for the prior knowledge of a 7% anomally rate. The precision was quite good but the recall for anomalies was not. The ROC cureve with the Youden index was then used to find the best threshold and proved to have better results.
#
# ### Variational autoencoder:
# For the variational autoencoder a similar arhitecture was used only that the latent spae was restricted to a normal distribution with means and standard deviations.
#
# This model performed very well and much better than the AE. The latent space showed more structure and was closer to a normal distribution.
